# %% [markdown]
# # Lab | SQL Queries 8
#
# In this lab, you will be using the [Sakila](https://dev.mysql.com/doc/sakila/en/) database of movie rentals. You have been using this database for a couple labs already, but if you need to get the data again, refer to the official [installation link](https://dev.mysql.com/doc/sakila/en/sakila-installation.html).
#
# The database is structured as follows:
# ![DB schema](https://education-team-2020.s3-eu-west-1.amazonaws.com/data-analytics/database-sakila-schema.png)
#
# ### Instructions
#
# 1. Rank films by length (filter out the rows with nulls or zeros in length column). Select only columns title, length and rank in your output.
# 2. Rank films by length within the `rating` category (filter out the rows with nulls or zeros in length column). In your output, only select the columns title, length, rating and rank.
# 3. How many films are there for each of the categories in the category table? **Hint**: Use appropriate join between the tables "category" and "film_category".
# 4. Which actor has appeared in the most films? **Hint**: You can create a join between the tables "actor" and "film actor" and count the number of times an actor appears.
# 5. Which is the most active customer (the customer that has rented the most number of films)? **Hint**: Use appropriate join between the tables "customer" and "rental" and count the `rental_id` for each customer.
#
# **Bonus**: Which is the most rented film? (The answer is Bucket Brotherhood).
#
# This query might require using more than one join statement. Give it a try. We will talk about queries with multiple join statements later in the lessons.
#
# **Hint**: You can use join between three tables - "Film", "Inventory", and "Rental" and count the *rental ids* for each film.

# %% [markdown]
# # Your solution here:

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import getpass  # To get the password without showing the input

# %% [markdown]
# ##### Prepare SQL connection

# %%
password = getpass.getpass()
connection_string = 'mysql+pymysql://root:' + password + '@localhost/bank'
engine = create_engine(connection_string)
# %load_ext sql
# %sql {connection_string}
# Out:
#  ········

# %%
# Your code:

# %%
# %%sql
# -- 1
# select title, length, RANK() over (ORDER BY length) ranks
# from sakila.film
# where length is not null and length > 0;
# Out:
#  * mysql+pymysql://root:***@localhost/bank
# 1000 rows affected.
# [('ALIEN CENTER', 46, 1),
#  ('IRON MOON', 46, 1),
#  ('KWAI HOMEWARD', 46, 1),
#  ('LABYRINTH LEAGUE', 46, 1),
#  ('RIDGEMONT SUBMARINE', 46, 1),
#  ('DIVORCE SHINING', 47, 6),
#  ('DOWNHILL ENOUGH', 47, 6),
#  ('HALLOWEEN NUTS', 47, 6),
#  ('HANOVER GALAXY', 47, 6),
#  ('HAWK CHILL', 47, 6),
#  ('SHANGHAI TYCOON', 47, 6),
#  ('SUSPECTS QUILLS', 47, 6),
#  ('ACE GOLDFINGER', 48, 13),
#  ('HEAVEN FREEDOM', 48, 13),
#  ('MIDSUMMER GROUNDHOG', 48, 13),
#  ('NOTTING SPEAKEASY', 48, 13),
#  ('ODDS BOOGIE', 48, 13),
#  ('PARADISE SABRINA', 48, 13),
#  ('PELICAN COMFORTS', 48, 13),
#  ('RUSH GOODFELLAS', 48, 13),
#  ('STEPMOM DREAM', 48, 13),
#  ('SUNSET RACER', 48, 13),
#  ('VALENTINE VANISHING', 48, 13),
#  ('DOORS PRESIDENT', 49, 24),
#  ('GROSSE WONDERFUL', 49, 24),
#  ('HEAVENLY GUN', 49, 24),
#  ('HOOK CHARIOTS', 49, 24),
#  ('HURRICANE AFFAIR', 49, 24),
#  ('ADAPTATION HOLES', 50, 29),
#  ('BLUES INSTINCT', 50, 29),
#  ('CROSSING DIVORCE', 50, 29),
#  ('LION UNCUT', 50, 29),
#  ('MUPPET MILE', 50, 29),
#  ('NATURAL STOCK', 50, 29),
#  ('PILOT HOOSIERS', 50, 29),
#  ('SMOKING BARBARELLA', 50, 29),
#  ('ZORRO ARK', 50, 29),
#  ('CHAMPION FLATLINERS', 51, 38),
#  ('DEEP CRUSADE', 51, 38),
#  ('ENGLISH BULWORTH', 51, 38),
#  ('EXCITEMENT EVE', 51, 38),
#  ('FRISCO FORREST', 51, 38),
#  ('HALL CASSIDY', 51, 38),
#  ('SIMON NORTH', 51, 38),
#  ('CADDYSHACK JEDI', 52, 45),
#  ('HARPER DYING', 52, 45),
#  ('LUST LOCK', 52, 45),
#  ('SIDE ARK', 52, 45),
#  ('SPARTACUS CHEAPER', 52, 45),
#  ('TROJAN TOMORROW', 52, 45),
#  ('WESTWARD SEABISCUIT', 52, 45),
#  ('BENEATH RUSH', 53, 52),
#  ('CABIN FLASH', 53, 52),
#  ('GUMP DATE', 53, 52),
#  ('MAGNIFICENT CHITTY', 53, 52),
#  ('MOVIE SHAKESPEARE', 53, 52),
#  ('PRIMARY GLASS', 53, 52),
#  ('SUMMER SCARFACE', 53, 52),
#  ('TEQUILA PAST', 53, 52),
#  ('THIN SAGEBRUSH', 53, 52),
#  ('AIRPORT POLLOCK', 54, 61),
#  ('GO PURPLE', 54, 61),
#  ('JUGGLER HARDLY', 54, 61),
#  ('KILL BROTHERHOOD', 54, 61),
#  ('OCTOBER SUBMARINE', 54, 61),
#  ('SENSE GREEK', 54, 61),
#  ('COAST RAINBOW', 55, 67),
#  ('WOLVES DESIRE', 55, 67),
#  ('BRIDE INTRIGUE', 56, 69),
#  ('CUPBOARD SINNERS', 56, 69),
#  ('DESTINY SATURDAY', 56, 69),
#  ('GOODFELLAS SALUTE', 56, 69),
#  ('MATRIX SNOWMAN', 56, 69),
#  ('ALTER VICTORY', 57, 74),
#  ('CRANES RESERVOIR', 57, 74),
#  ('DAWN POND', 57, 74),
#  ('DOCTOR GRAIL', 57, 74),
#  ('MOSQUITO ARMAGEDDON', 57, 74),
#  ('NOON PAPI', 57, 74),
#  ('STORM HAPPINESS', 57, 74),
#  ('CLOSER BANG', 58, 81),
#  ('DANCES NONE', 58, 81),
#  ('FANTASY TROOPERS', 58, 81),
#  ('JEKYLL FROGMEN', 58, 81),
#  ('OKLAHOMA JUMANJI', 58, 81),
#  ('RINGS HEARTBREAKERS', 58, 81),
#  ('SUPER WYOMING', 58, 81),
#  ('COMMANDMENTS EXPRESS', 59, 88),
#  ('DAUGHTER MADIGAN', 59, 88),
#  ('HEARTBREAKERS BRIGHT', 59, 88),
#  ('INTERVIEW LIAISONS', 59, 88),
#  ('JET NEIGHBORS', 59, 88),
#  ('LEGEND JEDI', 59, 88),
#  ('MINORITY KISS', 59, 88),
#  ('VISION TORQUE', 59, 88),
#  ('WHISPERER GIANT', 59, 88),
#  ('BUBBLE GROSSE', 60, 97),
#  ('JERSEY SASSY', 60, 97),
#  ('MOCKINGBIRD HOLLYWOOD', 60, 97),
#  ('PHANTOM GLORY', 60, 97),
#  ('PITY BOUND', 60, 97),
#  ('ROOM ROMAN', 60, 97),
#  ('SHAKESPEARE SADDLE', 60, 97),
#  ('SMILE EARRING', 60, 97),
#  ('BIRDS PERDITION', 61, 105),
#  ('BULWORTH COMMANDMENTS', 61, 105),
#  ('CAMELOT VACATION', 61, 105),
#  ('CASSIDY WYOMING', 61, 105),
#  ('CHINATOWN GLADIATOR', 61, 105),
#  ('DRIFTER COMMANDMENTS', 61, 105),
#  ('POLISH BROOKLYN', 61, 105),
#  ('RESERVOIR ADAPTATION', 61, 105),
#  ('TROUBLE DATE', 61, 105),
#  ('WATERFRONT DELIVERANCE', 61, 105),
#  ('AIRPLANE SIERRA', 62, 115),
#  ('ARABIA DOGMA', 62, 115),
#  ('HANGING DEEP', 62, 115),
#  ('MARS ROMAN', 62, 115),
#  ('SNOWMAN ROLLERCOASTER', 62, 115),
#  ('UNBREAKABLE KARATE', 62, 115),
#  ('ALADDIN CALENDAR', 63, 121),
#  ('BONNIE HOLOCAUST', 63, 121),
#  ('BORROWERS BEDAZZLED', 63, 121),
#  ('BOULEVARD MOB', 63, 121),
#  ('BUNCH MINDS', 63, 121),
#  ('DINOSAUR SECRETARY', 63, 121),
#  ('FORREST SONS', 63, 121),
#  ('INTOLERABLE INTENTIONS', 63, 121),
#  ('REUNION WITCHES', 63, 121),
#  ('CRAFT OUTFIELD', 64, 130),
#  ('DESERT POSEIDON', 64, 130),
#  ('METROPOLIS COMA', 64, 130),
#  ('MILE MULAN', 64, 130),
#  ('NOVOCAINE FLIGHT', 64, 130),
#  ('SLEEPLESS MONSOON', 64, 130),
#  ('TAXI KICK', 64, 130),
#  ('TRIP NEWTON', 64, 130),
#  ('VICTORY ACADEMY', 64, 130),
#  ('BARBARELLA STREETCAR', 65, 139),
#  ('CLUB GRAFFITI', 65, 139),
#  ('CONFESSIONS MAGUIRE', 65, 139),
#  ('FREDDY STORM', 65, 139),
#  ('HUNTING MUSKETEERS', 65, 139),
#  ('LOVELY JINGLE', 65, 139),
#  ('PATRIOT ROMAN', 65, 139),
#  ('CHARADE DUFFEL', 66, 146),
#  ('EVE RESURRECTION', 66, 146),
#  ('BUTCH PANTHER', 67, 148),
#  ('COMANCHEROS ENEMY', 67, 148),
#  ('EGG IGBY', 67, 148),
#  ('LADY STAGE', 67, 148),
#  ('LONELY ELEPHANT', 67, 148),
#  ('NORTH TEQUILA', 67, 148),
#  ('SHOOTIST SUPERFLY', 67, 148),
#  ('SILENCE KANE', 67, 148),
#  ('ARK RIDGEMONT', 68, 156),
#  ('DIVIDE MONSTER', 68, 156),
#  ('DOOM DANCING', 68, 156),
#  ('HUMAN GRAFFITI', 68, 156),
#  ('TOMATOES HELLFIGHTERS', 68, 156),
#  ('CRUELTY UNFORGIVEN', 69, 161),
#  ('FLYING HOOK', 69, 161),
#  ('HEAD STRANGER', 69, 161),
#  ('HOLLYWOOD ANONYMOUS', 69, 161),
#  ('LEBOWSKI SOLDIERS', 69, 161),
#  ('TIMBERLAND SKY', 69, 161),
#  ('CANDIDATE PERDITION', 70, 167),
#  ('CHANCE RESURRECTION', 70, 167),
#  ('CLUE GRAIL', 70, 167),
#  ('COLDBLOODED DARLING', 70, 167),
#  ('GUNFIGHT MOON', 70, 167),
#  ('LOUISIANA HARRY', 70, 167),
#  ('WEDDING APOLLO', 70, 167),
#  ('BLOOD ARGONAUTS', 71, 174),
#  ('CHARIOTS CONSPIRACY', 71, 174),
#  ('KNOCK WARLOCK', 71, 174),
#  ('MANNEQUIN WORST', 71, 174),
#  ('PRINCESS GIANT', 71, 174),
#  ('TEMPLE ATTRACTION', 71, 174),
#  ('TRAIN BUNCH', 71, 174),
#  ('BOWFINGER GABLES', 72, 181),
#  ('FICTION CHRISTMAS', 72, 181),
#  ('HARDLY ROBBERS', 72, 181),
#  ('MAUDE MOD', 72, 181),
#  ('BEDAZZLED MARRIED', 73, 185),
#  ('BRIGHT ENCOUNTERS', 73, 185),
#  ('BROTHERHOOD BLANKET', 73, 185),
#  ('FRIDA SLIPPER', 73, 185),
#  ('GODFATHER DIARY', 73, 185),
#  ('MUSKETEERS WAIT', 73, 185),
#  ('RANDOM GO', 73, 185),
#  ('REBEL AIRPORT', 73, 185),
#  ('SALUTE APOLLO', 73, 185),
#  ('STREETCAR INTENTIONS', 73, 185),
#  ('VALLEY PACKER', 73, 185),
#  ('WAKE JAWS', 73, 185),
#  ('ANGELS LIFE', 74, 197),
#  ('INFORMER DOUBLE', 74, 197),
#  ('JUMPING WRATH', 74, 197),
#  ('LUKE MUMMY', 74, 197),
#  ('MAGUIRE APACHE', 74, 197),
#  ('MODERN DORADO', 74, 197),
#  ('PEARL DESTINY', 74, 197),
#  ('RAINBOW SHOCK', 74, 197),
#  ('SILVERADO GOLDFINGER', 74, 197),
#  ('SNATCHERS MONTEZUMA', 74, 197),
#  ('TEEN APOLLO', 74, 197),
#  ('WORKING MICROCOSMOS', 74, 197),
#  ('BALLOON HOMEWARD', 75, 209),
#  ('CALIFORNIA BIRDS', 75, 209),
#  ('FIDDLER LOST', 75, 209),
#  ('HELLFIGHTERS SIERRA', 75, 209),
#  ('LOVER TRUMAN', 75, 209),
#  ('NETWORK PEAK', 75, 209),
#  ('NEWTON LABYRINTH', 75, 209),
#  ('SATISFACTION CONFIDENTIAL', 75, 209),
#  ('STAMPEDE DISTURBING', 75, 209),
#  ('WIZARD COLDBLOODED', 75, 209),
#  ('BOONDOCK BALLROOM', 76, 219),
#  ('COMFORTS RUSH', 76, 219),
#  ('DESIRE ALIEN', 76, 219),
#  ('DESTINATION JERK', 76, 219),
#  ('HAUNTED ANTITRUST', 76, 219),
#  ('ORANGE GRAPES', 76, 219),
#  ('VILLAIN DESPERATE', 76, 219),
#  ('BERETS AGENT', 77, 226),
#  ('ENEMY ODDS', 77, 226),
#  ('FELLOWSHIP AUTUMN', 77, 226),
#  ('MEMENTO ZOOLANDER', 77, 226),
#  ('MOD SECRETARY', 77, 226),
#  ('PICKUP DRIVING', 77, 226),
#  ('HOLIDAY GAMES', 78, 232),
#  ('INSIDER ARIZONA', 78, 232),
#  ('LANGUAGE COWBOY', 78, 232),
#  ('UNFAITHFUL KILL', 78, 232),
#  ('VOYAGE LEGALLY', 78, 232),
#  ('WATCH TRACY', 78, 232),
#  ('AMELIE HELLFIGHTERS', 79, 238),
#  ('ISHTAR ROCKETEER', 79, 238),
#  ('MOULIN WAKE', 79, 238),
#  ('SHOCK CABIN', 79, 238),
#  ('SPIKING ELEMENT', 79, 238),
#  ('WEREWOLF LOLA', 79, 238),
#  ('FLAMINGOS CONNECTICUT', 80, 244),
#  ('GARDEN ISLAND', 80, 244),
#  ('LOSER HUSTLER', 80, 244),
#  ('MEET CHOCOLATE', 80, 244),
#  ('PEAK FOREVER', 80, 244),
#  ('SADDLE ANTITRUST', 80, 244),
#  ('SEA VIRGIN', 80, 244),
#  ('SHAWSHANK BUBBLE', 80, 244),
#  ('TURN STAR', 80, 244),
#  ('WAR NOTTING', 80, 244),
#  ('CLASH FREDDY', 81, 254),
#  ('DESPERATE TRAINSPOTTING', 81, 254),
#  ('ROMAN PUNK', 81, 254),
#  ('ALONE TRIP', 82, 257),
#  ('ANYTHING SAVANNAH', 82, 257),
#  ('FROST HEAD', 82, 257),
#  ('PERFECT GROOVE', 82, 257),
#  ('RAIDERS ANTITRUST', 82, 257),
#  ('REIGN GENTLEMEN', 82, 257),
#  ('TYCOON GATHERING', 82, 257),
#  ('ATTRACTION NEWTON', 83, 264),
#  ('FUGITIVE MAGUIRE', 83, 264),
#  ('HUSTLER PARTY', 83, 264),
#  ('MOON BUNCH', 83, 264),
#  ('NONE SPIKING', 83, 264),
#  ('WARLOCK WEREWOLF', 83, 264),
#  ('DAISY MENAGERIE', 84, 270),
#  ('GONE TROUBLE', 84, 270),
#  ('GUYS FALCON', 84, 270),
#  ('HIGH ENCINO', 84, 270),
#  ('HONEY TIES', 84, 270),
#  ('IDOLS SNATCHERS', 84, 270),
#  ('ISLAND EXORCIST', 84, 270),
#  ('JEEPERS WEDDING', 84, 270),
#  ('PACKER MADIGAN', 84, 270),
#  ('PLUTO OLEANDER', 84, 270),
#  ('SAVANNAH TOWN', 84, 270),
#  ('SLING LUKE', 84, 270),
#  ('UPTOWN YOUNG', 84, 270),
#  ('AMISTAD MIDSUMMER', 85, 283),
#  ('BEVERLY OUTLAW', 85, 283),
#  ('BLACKOUT PRIVATE', 85, 283),
#  ('CANYON STOCK', 85, 283),
#  ('CASABLANCA SUPER', 85, 283),
#  ('EARTH VISION', 85, 283),
#  ('EGYPT TENENBAUMS', 85, 283),
#  ('ENDING CROWDS', 85, 283),
#  ('GHOST GROUNDHOG', 85, 283),
#  ('GRAIL FRANKENSTEIN', 85, 283),
#  ('LOLA AGENT', 85, 283),
#  ('OZ LIAISONS', 85, 283),
#  ('STAGE WORLD', 85, 283),
#  ('VARSITY TRIP', 85, 283),
#  ('WASTELAND DIVINE', 85, 283),
#  ('WINDOW SIDE', 85, 283),
#  ('WONKA SEA', 85, 283),
#  ('ACADEMY DINOSAUR', 86, 300),
#  ('ANNIE IDENTITY', 86, 300),
#  ('GANDHI KWAI', 86, 300),
#  ('MIDNIGHT WESTWARD', 86, 300),
#  ('YENTL IDAHO', 86, 300),
#  ('BANG KWAI', 87, 305),
#  ('CHEAPER CLYDE', 87, 305),
#  ('CONGENIALITY QUEST', 87, 305),
#  ('DEVIL DESIRE', 87, 305),
#  ('SLEUTH ORIENT', 87, 305),
#  ('TREATMENT JEKYLL', 87, 305),
#  ('DETAILS PACKER', 88, 311),
#  ('HOLY TADPOLE', 88, 311),
#  ('PURPLE MOVIE', 88, 311),
#  ('TERMINATOR CLUB', 88, 311),
#  ('BEAST HUNCHBACK', 89, 315),
#  ('BUTTERFLY CHOCOLAT', 89, 315),
#  ('DARES PLUTO', 89, 315),
#  ('GLEAMING JAWBREAKER', 89, 315),
#  ('PULP BEVERLY', 89, 315),
#  ('ROOTS REMEMBER', 89, 315),
#  ('BASIC EASY', 90, 321),
#  ('CIRCUS YOUTH', 90, 321),
#  ('FORWARD TEMPLE', 90, 321),
#  ('SECRET GROUNDHOG', 90, 321),
#  ('VERTIGO NORTHWEST', 90, 321),
#  ('ANTHEM LUKE', 91, 326),
#  ('FATAL HAUNTED', 91, 326),
#  ('FIGHT JAWBREAKER', 91, 326),
#  ('LICENSE WEEKEND', 91, 326),
#  ('TARZAN VIDEOTAPE', 91, 326),
#  ('TITANS JERK', 91, 326),
#  ('ANACONDA CONFESSIONS', 92, 332),
#  ('APACHE DIVINE', 92, 332),
#  ('CARIBBEAN LIBERTY', 92, 332),
#  ('CORE SUIT', 92, 332),
#  ('ENCOUNTERS CURTAIN', 92, 332),
#  ('KANE EXORCIST', 92, 332),
#  ('MYSTIC TRUMAN', 92, 332),
#  ('NATIONAL STORY', 92, 332),
#  ('OPPOSITE NECKLACE', 92, 332),
#  ('SUNDANCE INVASION', 92, 332),
#  ('TRUMAN CRAZY', 92, 332),
#  ('BILL OTHERS', 93, 343),
#  ('GOLDFINGER SENSIBILITY', 93, 343),
#  ('GREATEST NORTH', 93, 343),
#  ('HILLS NEIGHBORS', 93, 343),
#  ('PANKY SUBMARINE', 93, 343),
#  ('SHANE DARKNESS', 93, 343),
#  ('STING PERSONAL', 93, 343),
#  ('SUICIDES SILENCE', 93, 343),
#  ('ALICE FANTASIA', 94, 351),
#  ('DISTURBING SCARFACE', 94, 351),
#  ('FULL FLATLINERS', 94, 351),
#  ('STONE FIRE', 94, 351),
#  ('CLUELESS BUCKET', 95, 355),
#  ('HORN WORKING', 95, 355),
#  ('DRUMS DYNAMITE', 96, 357),
#  ('EARLY HOME', 96, 357),
#  ('EXPENDABLE STALLION', 97, 359),
#  ('INVASION CYCLONE', 97, 359),
#  ('LUCKY FLYING', 97, 359),
#  ('REAR TRADING', 97, 359),
#  ('BOUND CHEAPER', 98, 363),
#  ('EARRING INSTINCT', 98, 363),
#  ('FEUD FROGMEN', 98, 363),
#  ('LOST BIRD', 98, 363),
#  ('MADRE GABLES', 98, 363),
#  ('PREJUDICE OLEANDER', 98, 363),
#  ('SENSIBILITY REAR', 98, 363),
#  ('WISDOM WORKER', 98, 363),
#  ('ARMAGEDDON LOST', 99, 371),
#  ('DARKNESS WAR', 99, 371),
#  ('FRENCH HOLIDAY', 99, 371),
#  ('PATIENT SISTER', 99, 371),
#  ('PERDITION FARGO', 99, 371),
#  ('PET HAUNTING', 99, 371),
#  ('SABRINA MIDNIGHT', 99, 371),
#  ('TENENBAUMS COMMAND', 99, 371),
#  ('BEHAVIOR RUNAWAY', 100, 379),
#  ('BILKO ANONYMOUS', 100, 379),
#  ('DELIVERANCE MULHOLLAND', 100, 379),
#  ('DIVINE RESURRECTION', 100, 379),
#  ('FLATLINERS KILLER', 100, 379),
#  ('GUN BONNIE', 100, 379),
#  ('HAPPINESS UNITED', 100, 379),
#  ('HYDE DOCTOR', 100, 379),
#  ('PIRATES ROXANNE', 100, 379),
#  ('PUNK DIVORCE', 100, 379),
#  ('WITCHES PANIC', 100, 379),
#  ('WYOMING STORM', 100, 379),
#  ('CHOCOLAT HARRY', 101, 391),
#  ('CIDER DESIRE', 101, 391),
#  ('DWARFS ALTER', 101, 391),
#  ('GHOSTBUSTERS ELF', 101, 391),
#  ('ROOF CHAMPION', 101, 391),
#  ('RUNNER MADIGAN', 101, 391),
#  ('ZOOLANDER FICTION', 101, 391),
#  ('BOILED DARES', 102, 398),
#  ('FALCON VOLUME', 102, 398),
#  ('GIANT TROOPERS', 102, 398),
#  ('HEAVYWEIGHTS BEAST', 102, 398),
#  ('JEOPARDY ENCINO', 102, 398),
#  ('OPUS ICE', 102, 398),
#  ('PANIC CLUB', 102, 398),
#  ('ROBBERS JOON', 102, 398),
#  ('ROCK INSTINCT', 102, 398),
#  ('SCARFACE BANG', 102, 398),
#  ('TREASURE COMMAND', 102, 398),
#  ('BIRDCAGE CASPER', 103, 409),
#  ('BLINDNESS GUN', 103, 409),
#  ('FIREHOUSE VIETNAM', 103, 409),
#  ('GLASS DYING', 103, 409),
#  ('HOMEWARD CIDER', 103, 409),
#  ('IMPOSSIBLE PREJUDICE', 103, 409),
#  ('MOTHER OLEANDER', 103, 409),
#  ('PINOCCHIO SIMON', 103, 409),
#  ('STRANGELOVE DESIRE', 103, 409),
#  ('CROW GREASE', 104, 418),
#  ('DATE SPEED', 104, 418),
#  ('FEATHERS METAL', 104, 418),
#  ('MERMAID INSECTS', 104, 418),
#  ('SHIP WONDERLAND', 104, 418),
#  ('TITANIC BOONDOCK', 104, 418),
#  ('HUNGER ROOF', 105, 424),
#  ('JOON NORTHWEST', 105, 424),
#  ('MICROCOSMOS PARADISE', 105, 424),
#  ('MOB DUFFEL', 105, 424),
#  ('WON DARES', 105, 424),
#  ('ZHIVAGO CORE', 105, 424),
#  ('BED HIGHBALL', 106, 430),
#  ('DALMATIONS SWEDEN', 106, 430),
#  ('DEER VIRGINIAN', 106, 430),
#  ('GASLIGHT CRUSADE', 106, 430),
#  ('PRIVATE DROP', 106, 430),
#  ('SAGEBRUSH CLUELESS', 106, 430),
#  ('CHITTY LOCK', 107, 436),
#  ('DIARY PANIC', 107, 436),
#  ('EFFECT GLADIATOR', 107, 436),
#  ('HANKY OCTOBER', 107, 436),
#  ('HATE HANDICAP', 107, 436),
#  ('INTENTIONS EMPIRE', 107, 436),
#  ('MONSTER SPARTACUS', 107, 436),
#  ('PARTY KNOCK', 107, 436),
#  ('UNDEFEATED DALMATIONS', 107, 436),
#  ('WANDA CHAMBER', 107, 436),
#  ('AUTUMN CROW', 108, 446),
#  ('GORGEOUS BINGO', 108, 446),
#  ('HANDICAP BOONDOCK', 108, 446),
#  ('LORD ARIZONA', 108, 446),
#  ('SWEETHEARTS SUSPECTS', 108, 446),
#  ('COMA HEAD', 109, 451),
#  ('HOUSE DYNAMITE', 109, 451),
#  ('PANTHER REDS', 109, 451),
#  ('PARK CITIZEN', 109, 451),
#  ('RUGRATS SHAKESPEARE', 109, 451),
#  ('SECRETS PARADISE', 109, 451),
#  ('WHALE BIKINI', 109, 451),
#  ('CELEBRITY HORN', 110, 458),
#  ('DRUMLINE CYCLONE', 110, 458),
#  ('HIGHBALL POTTER', 110, 458),
#  ('LEAGUE HELLFIGHTERS', 110, 458),
#  ('REMEMBER DIARY', 110, 458),
#  ('SAMURAI LION', 110, 458),
#  ('SEATTLE EXPECATIONS', 110, 458),
#  ('SNATCH SLIPPER', 110, 458),
#  ('TRAP GUYS', 110, 458),
#  ('FROGMEN BREAKING', 111, 467),
#  ('GROOVE FICTION', 111, 467),
#  ('SIEGE MADRE', 111, 467),
#  ('SUIT WALLS', 111, 467),
#  ('TIES HUNGER', 111, 467),
#  ('WIND PHANTOM', 111, 467),
#  ('WONDERLAND CHRISTMAS', 111, 467),
#  ('CAT CONEHEADS', 112, 474),
#  ('CONEHEADS SMOOCHY', 112, 474),
#  ('CONVERSATION DOWNHILL', 112, 474),
#  ('CROWDS TELEMARK', 112, 474),
#  ('CRUSADE HONEY', 112, 474),
#  ('FORRESTER COMANCHEROS', 112, 474),
#  ('JAWS HARRY', 112, 474),
#  ('QUILLS BULL', 112, 474),
#  ('SEABISCUIT PUNK', 112, 474),
#  ('SPY MILE', 112, 474),
#  ('STAGECOACH ARMAGEDDON', 112, 474),
#  ('WAIT CIDER', 112, 474),
#  ('WATERSHIP FRONTIER', 112, 474),
#  ('AMADEUS HOLY', 113, 487),
#  ('ATTACKS HATE', 113, 487),
#  ('BANGER PINOCCHIO', 113, 487),
#  ('DAY UNFAITHFUL', 113, 487),
#  ('LADYBUGS ARMAGEDDON', 113, 487),
#  ('LEGALLY SECRETARY', 113, 487),
#  ('SHEPHERD MIDSUMMER', 113, 487),
#  ('STATE WASTELAND', 113, 487),
#  ('ALABAMA DEVIL', 114, 495),
#  ('BLADE POLISH', 114, 495),
#  ('CARRIE BUNCH', 114, 495),
#  ('CHAINSAW UPTOWN', 114, 495),
#  ('CHASING FIGHT', 114, 495),
#  ('GILBERT PELICAN', 114, 495),
#  ('MARRIED GO', 114, 495),
#  ('PRIDE ALAMO', 114, 495),
#  ('SUGAR WONKA', 114, 495),
#  ('SUPERFLY TRIP', 114, 495),
#  ('CONNECTION MICROCOSMOS', 115, 505),
#  ('ELEMENT FREDDY', 115, 505),
#  ('GLORY TRACY', 115, 505),
#  ('OSCAR GOLD', 115, 505),
#  ('POTTER CONNECTICUT', 115, 505),
#  ('PRIX UNDEFEATED', 115, 505),
#  ('TROOPERS METAL', 115, 505),
#  ('DUCK RACER', 116, 512),
#  ('INSTINCT AIRPORT', 116, 512),
#  ('MADIGAN DORADO', 116, 512),
#  ('WORDS HUNTER', 116, 512),
#  ('AFFAIR PREJUDICE', 117, 516),
#  ('CHAMBER ITALIAN', 117, 516),
#  ('GRAFFITI LOVE', 117, 516),
#  ('MAGIC MALLRATS', 117, 516),
#  ('RESURRECTION SILVERADO', 117, 516),
#  ('BACKLASH UNDEFEATED', 118, 521),
#  ('FIDELITY DEVIL', 118, 521),
#  ('JAWBREAKER BROOKLYN', 118, 521),
#  ('ORIENT CLOSER', 118, 521),
#  ('OTHERS SOUP', 118, 521),
#  ('PATHS CONTROL', 118, 521),
#  ('PERSONAL LADYBUGS', 118, 521),
#  ('ROUGE SQUAD', 118, 521),
#  ('APOCALYPSE FLAMINGOS', 119, 529),
#  ('BUGSY SONG', 119, 529),
#  ('DUMBO LUST', 119, 529),
#  ('GAMES BOWFINGER', 119, 529),
#  ('IDENTITY LOVER', 119, 529),
#  ('STRANGERS GRAFFITI', 119, 529),
#  ('CALENDAR GUNFIGHT', 120, 535),
#  ('COMMAND DARLING', 120, 535),
#  ('DAZED PUNK', 120, 535),
#  ('DOLLS RAGE', 120, 535),
#  ('KARATE MOON', 120, 535),
#  ('LOCK REAR', 120, 535),
#  ('ORDER BETRAYED', 120, 535),
#  ('RAGE GAMES', 120, 535),
#  ('UNTOUCHABLES SUNRISE', 120, 535),
#  ('ARIZONA BANG', 121, 544),
#  ('BOOGIE AMELIE', 121, 544),
#  ('BRANNIGAN SUNRISE', 121, 544),
#  ('DANGEROUS UPTOWN', 121, 544),
#  ('HARRY IDAHO', 121, 544),
#  ('JUMANJI BLADE', 121, 544),
#  ('PARIS WEEKEND', 121, 544),
#  ('PURE RUNNER', 121, 544),
#  ('BEACH HEARTBREAKERS', 122, 552),
#  ('BETRAYED REAR', 122, 552),
#  ('CHICKEN HELLFIGHTERS', 122, 552),
#  ('CONFUSED CANDLES', 122, 552),
#  ('DECEIVER BETRAYED', 122, 552),
#  ('DOGMA FAMILY', 122, 552),
#  ('EXTRAORDINARY CONQUERER', 122, 552),
#  ('HOURS RAGE', 122, 552),
#  ('ILLUSION AMELIE', 122, 552),
#  ('MIGHTY LUCK', 122, 552),
#  ('VANILLA DAY', 122, 552),
#  ('BREAKFAST GOLDFINGER', 123, 563),
#  ('FLASH WARS', 123, 563),
#  ('INSECTS STONE', 123, 563),
#  ('MASK PEACH', 123, 563),
#  ('REEF SALUTE', 123, 563),
#  ('SWARM GOLD', 123, 563),
#  ('VANISHING ROCKY', 123, 563),
#  ('CHISUM BEHAVIOR', 124, 570),
#  ('CLONES PINOCCHIO', 124, 570),
#  ('JINGLE SAGEBRUSH', 124, 570),
#  ('SPEED SUIT', 124, 570),
#  ('BULL SHAWSHANK', 125, 574),
#  ('DONNIE ALLEY', 125, 574),
#  ('FISH OPUS', 125, 574),
#  ('GENTLEMEN STAGE', 125, 574),
#  ('HUNTER ALTER', 125, 574),
#  ('SAINTS BRIDE', 125, 574),
#  ('SHINING ROSES', 125, 574),
#  ('ALAMO VIDEOTAPE', 126, 581),
#  ('ELEPHANT TROJAN', 126, 581),
#  ('FREAKY POCUS', 126, 581),
#  ('MONTEZUMA COMMAND', 126, 581),
#  ('PAJAMA JAWBREAKER', 126, 581),
#  ('SINNERS ATLANTIS', 126, 581),
#  ('VAMPIRE WHALE', 126, 581),
#  ('WOMEN DORADO', 126, 581),
#  ('WONDERFUL DROP', 126, 581),
#  ('ARGONAUTS TOWN', 127, 590),
#  ('GUNFIGHTER MUSSOLINI', 127, 590),
#  ('MALTESE HOPE', 127, 590),
#  ('SEVEN SWARM', 127, 590),
#  ('SUBMARINE BED', 127, 590),
#  ('GALAXY SWEETHEARTS', 128, 595),
#  ('HOLES BRANNIGAN', 128, 595),
#  ('JEDI BENEATH', 128, 595),
#  ('NOTORIOUS REUNION', 128, 595),
#  ('PAPI NECKLACE', 128, 595),
#  ('USUAL UNTOUCHABLES', 128, 595),
#  ('WARS PLUTO', 128, 595),
#  ('AMERICAN CIRCUS', 129, 602),
#  ('BAREFOOT MANCHURIAN', 129, 602),
#  ('GOSFORD DONNIE', 129, 602),
#  ('MUSIC BOONDOCK', 129, 602),
#  ('OUTFIELD MASSACRE', 129, 602),
#  ('SLEEPING SUSPECTS', 129, 602),
#  ('UNFORGIVEN ZOOLANDER', 129, 602),
#  ('AFRICAN EGG', 130, 609),
#  ('DARKO DORADO', 130, 609),
#  ('FARGO GANDHI', 130, 609),
#  ('JASON TRAP', 130, 609),
#  ('MAJESTIC FLOATS', 130, 609),
#  ('STALLION SUNDANCE', 130, 609),
#  ('FANTASIA PARK', 131, 615),
#  ('FOREVER CANDIDATE', 131, 615),
#  ('ICE CROSSING', 131, 615),
#  ('NEMO CAMPUS', 131, 615),
#  ('OPEN AFRICAN', 131, 615),
#  ('CHOCOLATE DUCK', 132, 620),
#  ('DUDE BLINDNESS', 132, 620),
#  ('NECKLACE OUTBREAK', 132, 620),
#  ('PLATOON INSTINCT', 132, 620),
#  ('SKY MIRACLE', 132, 620),
#  ('STREAK RIDGEMONT', 132, 620),
#  ('TRAINSPOTTING STRANGERS', 132, 620),
#  ('VOLUME HOUSE', 132, 620),
#  ('BUCKET BROTHERHOOD', 133, 628),
#  ('CURTAIN VIDEOTAPE', 133, 628),
#  ('DRAGONFLY STRANGERS', 133, 628),
#  ('FREEDOM CLEOPATRA', 133, 628),
#  ('MALLRATS UNITED', 133, 628),
#  ('JUNGLE CLOSER', 134, 633),
#  ('PITTSBURGH HUNCHBACK', 134, 633),
#  ('ROBBERY BRIGHT', 134, 633),
#  ('SPLENDOR PATTON', 134, 633),
#  ('WEEKEND PERSONAL', 134, 633),
#  ('CANDLES GRAPES', 135, 638),
#  ('DREAM PICKUP', 135, 638),
#  ('GREASE YOUTH', 135, 638),
#  ('INDIAN LOVE', 135, 638),
#  ('JAPANESE RUN', 135, 638),
#  ('MONEY HAROLD', 135, 638),
#  ('SIERRA DIVIDE', 135, 638),
#  ('SUNRISE LEAGUE', 135, 638),
#  ('THIEF PELICAN', 135, 638),
#  ('WALLS ARTIST', 135, 638),
#  ('ALASKA PHANTOM', 136, 648),
#  ('BRINGING HYSTERICAL', 136, 648),
#  ('CRAZY HOME', 136, 648),
#  ('HOLLOW JEOPARDY', 136, 648),
#  ('MAKER GABLES', 136, 648),
#  ('PIANIST OUTFIELD', 136, 648),
#  ('REAP UNFAITHFUL', 136, 648),
#  ('SQUAD FISH', 136, 648),
#  ('TOWN ARK', 136, 648),
#  ('ARSENIC INDEPENDENCE', 137, 657),
#  ('GRIT CLOCKWORK', 137, 657),
#  ('LIFE TWISTED', 137, 657),
#  ('LOSE INCH', 137, 657),
#  ('PHILADELPHIA WIFE', 137, 657),
#  ('POLLOCK DELIVERANCE', 137, 657),
#  ('SCORPION APOLLO', 137, 657),
#  ('SLEEPY JAPANESE', 137, 657),
#  ('WILLOW TRACY', 137, 657),
#  ('EXPECATIONS NATURAL', 138, 666),
#  ('LIBERTY MAGNIFICENT', 138, 666),
#  ('MAIDEN HOME', 138, 666),
#  ('POCUS PULP', 138, 666),
#  ('SPINAL ROCKY', 138, 666),
#  ('SPIRITED CASUALTIES', 138, 666),
#  ('CLYDE THEORY', 139, 672),
#  ('CREATURES SHAKESPEARE', 139, 672),
#  ('DORADO NOTTING', 139, 672),
#  ('GROUNDHOG UNCUT', 139, 672),
#  ('HOPE TOOTSIE', 139, 672),
#  ('HORROR REIGN', 139, 672),
#  ('SHRUNK DIVINE', 139, 672),
#  ('STRANGER STRANGERS', 139, 672),
#  ('TRAFFIC HOBBIT', 139, 672),
#  ('VOICE PEACH', 139, 672),
#  ('WORKER TARZAN', 139, 672),
#  ('EAGLES PANKY', 140, 683),
#  ('GRACELAND DYNAMITE', 140, 683),
#  ('LIAISONS SWEET', 140, 683),
#  ('LOATHING LEGALLY', 140, 683),
#  ('STEERS ARMAGEDDON', 140, 683),
#  ('DISCIPLE MOTHER', 141, 688),
#  ('DYNAMITE TARZAN', 141, 688),
#  ('HOCUS FRIDA', 141, 688),
#  ('HOMICIDE PEACH', 141, 688),
#  ('KISSING DOLLS', 141, 688),
#  ('SPICE SORORITY', 141, 688),
#  ('SUN CONFESSIONS', 141, 688),
#  ('BIKINI BORROWERS', 142, 695),
#  ('CHILL LUCK', 142, 695),
#  ('FERRIS MOTHER', 142, 695),
#  ('MILLION ACE', 142, 695),
#  ('TOMORROW HUSTLER', 142, 695),
#  ('TRACY CIDER', 142, 695),
#  ('VANISHED GARDEN', 142, 695),
#  ('CINCINATTI WHISPERER', 143, 702),
#  ('CLOCKWORK PARADISE', 143, 702),
#  ('CROOKED FROGMEN', 143, 702),
#  ('DETECTIVE VISION', 143, 702),
#  ('ENCINO ELF', 143, 702),
#  ('SOUTH WAIT', 143, 702),
#  ('STEEL SANTA', 143, 702),
#  ('DANCING FEVER', 144, 709),
#  ('FACTORY DRAGON', 144, 709),
#  ('LAMBS CINCINATTI', 144, 709),
#  ('PACIFIC AMISTAD', 144, 709),
#  ('PRESIDENT BANG', 144, 709),
#  ('STRICTLY SCARFACE', 144, 709),
#  ('TOWERS HURRICANE', 144, 709),
#  ('VIRTUAL SPOILERS', 144, 709),
#  ('FLOATS GARDEN', 145, 717),
#  ('NUTS TIES', 145, 717),
#  ('PAYCHECK WAIT', 145, 717),
#  ('ROCKY WAR', 145, 717),
#  ('RUN PACIFIC', 145, 717),
#  ('VACATION BOONDOCK', 145, 717),
#  ('VIDEOTAPE ARSENIC', 145, 717),
#  ('CHAPLIN LICENSE', 146, 724),
#  ('COWBOY DOOM', 146, 724),
#  ('HALF OUTFIELD', 146, 724),
#  ('HAMLET WISDOM', 146, 724),
#  ('MOURNING PURPLE', 146, 724),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 147, 729),
#  ('DIRTY ACE', 147, 729),
#  ('LIES TREATMENT', 147, 729),
#  ('MADISON TRAP', 147, 729),
#  ('MENAGERIE RUSHMORE', 147, 729),
#  ('RACER EGG', 147, 729),
#  ('RANGE MOONWALKER', 147, 729),
#  ('SCISSORHANDS SLUMS', 147, 729),
#  ('SLUMS DUCK', 147, 729),
#  ('ARMY FLINTSTONES', 148, 738),
#  ('BLANKET BEVERLY', 148, 738),
#  ('EASY GLADIATOR', 148, 738),
#  ('FIREBALL PHILADELPHIA', 148, 738),
#  ('FLINTSTONES HAPPINESS', 148, 738),
#  ('OUTLAW HANKY', 148, 738),
#  ('TELEGRAPH VOYAGE', 148, 738),
#  ('COLOR PHILADELPHIA', 149, 745),
#  ('HOLOCAUST HIGHBALL', 149, 745),
#  ('MINDS TRUMAN', 149, 745),
#  ('NIGHTMARE CHILL', 149, 745),
#  ('RIVER OUTLAW', 149, 745),
#  ('SPIRIT FLINTSTONES', 149, 745),
#  ('ALI FOREVER', 150, 751),
#  ('BINGO TALENTED', 150, 751),
#  ('CHRISTMAS MOONSHINE', 150, 751),
#  ('CLEOPATRA DEVIL', 150, 751),
#  ('GRINCH MASSAGE', 150, 751),
#  ('HYSTERICAL GRAIL', 150, 751),
#  ('RUSHMORE MERMAID', 150, 751),
#  ('SATURDAY LAMBS', 150, 751),
#  ('BEETHOVEN EXORCIST', 151, 759),
#  ('CAROL TEXAS', 151, 759),
#  ('HUNCHBACK IMPOSSIBLE', 151, 759),
#  ('MASKED BUBBLE', 151, 759),
#  ('SCHOOL JACKET', 151, 759),
#  ('SPOILERS HELLFIGHTERS', 151, 759),
#  ('STRAIGHT HOURS', 151, 759),
#  ('CENTER DINOSAUR', 152, 766),
#  ('ELIZABETH SHANE', 152, 766),
#  ('LUCK OPUS', 152, 766),
#  ('SISTER FREDDY', 152, 766),
#  ('TELEMARK HEARTBREAKERS', 152, 766),
#  ('TOURIST PELICAN', 152, 766),
#  ('TUXEDO MILE', 152, 766),
#  ('TWISTED PIRATES', 152, 766),
#  ('WAGON JAWS', 152, 766),
#  ('APOLLO TEEN', 153, 775),
#  ('BABY HALL', 153, 775),
#  ('CROSSROADS CASUALTIES', 153, 775),
#  ('EDGE KISSING', 153, 775),
#  ('GOLDMINE TYCOON', 153, 775),
#  ('LEATHERNECKS DWARFS', 153, 775),
#  ('RIGHT CRANES', 153, 775),
#  ('ROLLERCOASTER BRINGING', 153, 775),
#  ('RULES HUMAN', 153, 775),
#  ('DOUBTFIRE LABYRINTH', 154, 784),
#  ('DURHAM PANKY', 154, 784),
#  ('GOLD RIVER', 154, 784),
#  ('RAGING AIRPLANE', 154, 784),
#  ('SANTA PARIS', 154, 784),
#  ('SASSY PACKER', 154, 784),
#  ('SHREK LICENSE', 154, 784),
#  ('ELF MURDER', 155, 791),
#  ('FAMILY SWEET', 155, 791),
#  ('GRAPES FURY', 155, 791),
#  ('LOLITA WORLD', 155, 791),
#  ('PSYCHO SHRUNK', 155, 791),
#  ('TADPOLE PARK', 155, 791),
#  ('FINDING ANACONDA', 156, 797),
#  ('GRADUATE LORD', 156, 797),
#  ('OPERATION OPERATION', 156, 797),
#  ('SLIPPER FIDELITY', 156, 797),
#  ('HOBBIT ALIEN', 157, 801),
#  ('INDEPENDENCE HOTEL', 157, 801),
#  ('MULHOLLAND BEAST', 157, 801),
#  ('PAST SUICIDES', 157, 801),
#  ('TOOTSIE PILOT', 157, 801),
#  ('VOLCANO TEXAS', 157, 801),
#  ('ENOUGH RAGING', 158, 807),
#  ('FEVER EMPIRE', 158, 807),
#  ('FOOL MOCKINGBIRD', 158, 807),
#  ('MONTEREY LABYRINTH', 158, 807),
#  ('ROAD ROXANNE', 158, 807),
#  ('SECRETARY ROUGE', 158, 807),
#  ('DRIVER ANNIE', 159, 813),
#  ('FRANKENSTEIN STRANGER', 159, 813),
#  ('MALKOVICH PET', 159, 813),
#  ('NEWSIES STORY', 159, 813),
#  ('POSEIDON FOREVER', 159, 813),
#  ('WEST LION', 159, 813),
#  ('BEAR GRACELAND', 160, 819),
#  ('IGBY MAKER', 160, 819),
#  ('MULAN MOON', 160, 819),
#  ('MUMMY CREATURES', 160, 819),
#  ('PEACH INNOCENT', 160, 819),
#  ('STOCK GLASS', 160, 819),
#  ('BROOKLYN DESERT', 161, 825),
#  ('DADDY PITTSBURGH', 161, 825),
#  ('GABLES METROPOLIS', 161, 825),
#  ('KILLER INNOCENT', 161, 825),
#  ('MASSAGE IMAGE', 161, 825),
#  ('METAL ARMAGEDDON', 161, 825),
#  ('NEIGHBORS CHARADE', 161, 825),
#  ('OLEANDER CLUE', 161, 825),
#  ('WASH HEAVENLY', 161, 825),
#  ('BADMAN DAWN', 162, 834),
#  ('BIRCH ANTITRUST', 162, 834),
#  ('LOVERBOY ATTACKS', 162, 834),
#  ('MIRACLE VIRTUAL', 162, 834),
#  ('ROSES TREASURE', 162, 834),
#  ('BIRD INDEPENDENCE', 163, 839),
#  ('CASPER DRAGONFLY', 163, 839),
#  ('EVERYONE CRAFT', 163, 839),
#  ('GILMORE BOILED', 163, 839),
#  ('KISS GLORY', 163, 839),
#  ('QUEEN LUKE', 163, 839),
#  ('STORY SIDE', 163, 839),
#  ('CLERKS ANGELS', 164, 846),
#  ('MISSION ZOOLANDER', 164, 846),
#  ('UNITED PILOT', 164, 846),
#  ('VIRGINIAN PLUTO', 164, 846),
#  ('CITIZEN SHREK', 165, 850),
#  ('DARLING BREAKING', 165, 850),
#  ('MASSACRE USUAL', 165, 850),
#  ('SONG HEDWIG', 165, 850),
#  ('SPEAKEASY DATE', 165, 850),
#  ('CONTACT ANONYMOUS', 166, 855),
#  ('GREEDY ROOTS', 166, 855),
#  ('MINE TITANS', 166, 855),
#  ('MOTIONS DETAILS', 166, 855),
#  ('MURDER ANTITRUST', 166, 855),
#  ('CAMPUS REMEMBER', 167, 860),
#  ('ESCAPE METROPOLIS', 167, 860),
#  ('EXORCIST STING', 167, 860),
#  ('INCH JET', 167, 860),
#  ('LESSON CLEOPATRA', 167, 860),
#  ('REQUIEM TYCOON', 167, 860),
#  ('SHOW LORD', 167, 860),
#  ('ANTITRUST TOMATOES', 168, 867),
#  ('DYING MAKER', 168, 867),
#  ('HAROLD FRENCH', 168, 867),
#  ('TRANSLATION SUMMER', 168, 867),
#  ('AGENT TRUMAN', 169, 871),
#  ('BREAKING HOME', 169, 871),
#  ('HEDWIG ALTER', 169, 871),
#  ('KENTUCKIAN GIANT', 169, 871),
#  ('OUTBREAK DIVINE', 169, 871),
#  ('SOUP WISDOM', 169, 871),
#  ('ARTIST COLDBLOODED', 170, 877),
#  ('ATLANTIS CAUSE', 170, 877),
#  ('DRAGON SQUAD', 170, 877),
#  ('TRADING PINOCCHIO', 170, 877),
#  ('DUFFEL APOCALYPSE', 171, 881),
#  ('JERICHO MULAN', 171, 881),
#  ('KRAMER CHOCOLATE', 171, 881),
#  ('MAGNOLIA FORRESTER', 171, 881),
#  ('MOONSHINE CABIN', 171, 881),
#  ('ROXANNE REBEL', 171, 881),
#  ('TRAMP OTHERS', 171, 881),
#  ('WORLD LEATHERNECKS', 171, 881),
#  ('CONNECTICUT TRAMP', 172, 889),
#  ('CREEPERS KANE', 172, 889),
#  ('EYES DRIVING', 172, 889),
#  ('IDAHO LOVE', 172, 889),
#  ('JERK PAYCHECK', 172, 889),
#  ('NORTHWEST POLISH', 172, 889),
#  ('TIGHTS DAWN', 172, 889),
#  ('UNCUT SUICIDES', 172, 889),
#  ('BALLROOM MOCKINGBIRD', 173, 897),
#  ('CONQUERER NUTS', 173, 897),
#  ('FIRE WOLVES', 173, 897),
#  ('GLADIATOR WESTWARD', 173, 897),
#  ('PIZZA JUMANJI', 173, 897),
#  ('TALENTED HOMICIDE', 173, 897),
#  ('VELVET TERMINATOR', 173, 897),
#  ('EVOLUTION ALTER', 174, 904),
#  ('ITALIAN AFRICAN', 174, 904),
#  ('JADE BUNCH', 174, 904),
#  ('LIGHTS DEER', 174, 904),
#  ('UPRISING UPTOWN', 174, 904),
#  ('VIETNAM SMOOCHY', 174, 904),
#  ('BEAUTY GREASE', 175, 910),
#  ('DRIVING POLISH', 175, 910),
#  ('LAWRENCE LOVE', 175, 910),
#  ('MODEL FISH', 175, 910),
#  ('PATTON INTERVIEW', 175, 910),
#  ('SPLASH GUMP', 175, 910),
#  ('BRAVEHEART HUMAN', 176, 916),
#  ('CAPER MOTIONS', 176, 916),
#  ('CYCLONE FAMILY', 176, 916),
#  ('DRACULA CRYSTAL', 176, 916),
#  ('ENTRAPMENT SATISFACTION', 176, 916),
#  ('GATHERING CALENDAR', 176, 916),
#  ('GREEK EVERYONE', 176, 916),
#  ('HOOSIERS BIRDCAGE', 176, 916),
#  ('SWEDEN SHINING', 176, 916),
#  ('WRATH MILE', 176, 916),
#  ('DOUBLE WRATH', 177, 926),
#  ('DOZEN LION', 177, 926),
#  ('EMPIRE MALKOVICH', 177, 926),
#  ('MANCHURIAN CURTAIN', 177, 926),
#  ('QUEST MUSSOLINI', 177, 926),
#  ('RIDER CADDYSHACK', 177, 926),
#  ('DROP WATERFRONT', 178, 932),
#  ('EXPRESS LONELY', 178, 932),
#  ('FURY MURDER', 178, 932),
#  ('IMAGE PRINCESS', 178, 932),
#  ('INNOCENT USUAL', 178, 932),
#  ('MADNESS ATTACKS', 178, 932),
#  ('NAME DETECTIVE', 178, 932),
#  ('ROCKETEER MOTHER', 178, 932),
#  ('WARDROBE PHANTOM', 178, 932),
#  ('WRONG BEHAVIOR', 178, 932),
#  ('ANONYMOUS HUMAN', 179, 942),
#  ('BORN SPINAL', 179, 942),
#  ('CASUALTIES ENCINO', 179, 942),
#  ('CAUSE DATE', 179, 942),
#  ('FLIGHT LIES', 179, 942),
#  ('KICK SAVANNAH', 179, 942),
#  ('POTLUCK MIXED', 179, 942),
#  ('REDEMPTION COMFORTS', 179, 942),
#  ('SLACKER LIAISONS', 179, 942),
#  ('TEXAS WATCH', 179, 942),
#  ('TORQUE BOUND', 179, 942),
#  ('VIRGIN DAISY', 179, 942),
#  ('YOUTH KICK', 179, 942),
#  ('ALLEY EVOLUTION', 180, 955),
#  ('CONFIDENTIAL INTERVIEW', 180, 955),
#  ('IMPACT ALADDIN', 180, 955),
#  ('MIXED DOORS', 180, 955),
#  ('MUSSOLINI SPOILERS', 180, 955),
#  ('NASH CHOCOLAT', 180, 955),
#  ('SOMETHING DUCK', 180, 955),
#  ('ANALYZE HOOSIERS', 181, 962),
#  ('HAUNTING PIANIST', 181, 962),
#  ('HOTEL HAPPINESS', 181, 962),
#  ('INTRIGUE WORST', 181, 962),
#  ('JACKET FRISCO', 181, 962),
#  ('LAWLESS VISION', 181, 962),
#  ('LOVE SUICIDES', 181, 962),
#  ('RUNAWAY TENENBAUMS', 181, 962),
#  ('STAR OPERATION', 181, 962),
#  ('WILD APOLLO', 181, 962),
#  ('BAKED CLEOPATRA', 182, 972),
#  ('MONSOON CAUSE', 182, 972),
#  ('RECORDS ZORRO', 182, 972),
#  ('REDS POCUS', 182, 972),
#  ('SATURN NAME', 182, 972),
#  ('SEARCHERS WAIT', 182, 972),
#  ('CATCH AMISTAD', 183, 978),
#  ('FRONTIER CABIN', 183, 978),
#  ('SCALAWAG DUCK', 183, 978),
#  ('WIFE TURN', 183, 978),
#  ('YOUNG LANGUAGE', 183, 978),
#  ('CONSPIRACY SPIRIT', 184, 983),
#  ('CRYSTAL BREAKING', 184, 983),
#  ('KING EVOLUTION', 184, 983),
#  ('MOONWALKER FOOL', 184, 983),
#  ('SMOOCHY CONTROL', 184, 983),
#  ('SONS INTERVIEW', 184, 983),
#  ('SORORITY QUEEN', 184, 983),
#  ('THEORY MERMAID', 184, 983),
#  ('CHICAGO NORTH', 185, 991),
#  ('CONTROL ANTHEM', 185, 991),
#  ('DARN FORRESTER', 185, 991),
#  ('GANGS PRIDE', 185, 991),
#  ('HOME PITY', 185, 991),
#  ('MUSCLE BRIGHT', 185, 991),
#  ('POND SEATTLE', 185, 991),
#  ('SOLDIERS EVOLUTION', 185, 991),
#  ('SWEET BROTHERHOOD', 185, 991),
#  ('WORST BANGER', 185, 991)]

# %%
# %%sql
# -- 2
# select title, length, rating, rank() over (partition by rating order by length desc) as ranks
# from sakila.film
# where length is not null and length > 0;
# Out:
#  * mysql+pymysql://root:***@localhost/bank
# 1000 rows affected.
# [('CONTROL ANTHEM', 185, 'G', 1),
#  ('DARN FORRESTER', 185, 'G', 1),
#  ('MUSCLE BRIGHT', 185, 'G', 1),
#  ('MOONWALKER FOOL', 184, 'G', 4),
#  ('CATCH AMISTAD', 183, 'G', 5),
#  ('YOUNG LANGUAGE', 183, 'G', 5),
#  ('BAKED CLEOPATRA', 182, 'G', 7),
#  ('INTRIGUE WORST', 181, 'G', 8),
#  ('LAWLESS VISION', 181, 'G', 8),
#  ('MUSSOLINI SPOILERS', 180, 'G', 10),
#  ('CASUALTIES ENCINO', 179, 'G', 11),
#  ('POTLUCK MIXED', 179, 'G', 11),
#  ('TORQUE BOUND', 179, 'G', 11),
#  ('WARDROBE PHANTOM', 178, 'G', 14),
#  ('EMPIRE MALKOVICH', 177, 'G', 15),
#  ('CAPER MOTIONS', 176, 'G', 16),
#  ('DRACULA CRYSTAL', 176, 'G', 16),
#  ('HOOSIERS BIRDCAGE', 176, 'G', 16),
#  ('BEAUTY GREASE', 175, 'G', 19),
#  ('ITALIAN AFRICAN', 174, 'G', 20),
#  ('BALLROOM MOCKINGBIRD', 173, 'G', 21),
#  ('CONQUERER NUTS', 173, 'G', 21),
#  ('DUFFEL APOCALYPSE', 171, 'G', 23),
#  ('ATLANTIS CAUSE', 170, 'G', 24),
#  ('EXORCIST STING', 167, 'G', 25),
#  ('CITIZEN SHREK', 165, 'G', 26),
#  ('CLERKS ANGELS', 164, 'G', 27),
#  ('BIRD INDEPENDENCE', 163, 'G', 28),
#  ('DADDY PITTSBURGH', 161, 'G', 29),
#  ('MULAN MOON', 160, 'G', 30),
#  ('MALKOVICH PET', 159, 'G', 31),
#  ('NEWSIES STORY', 159, 'G', 31),
#  ('WEST LION', 159, 'G', 31),
#  ('MONTEREY LABYRINTH', 158, 'G', 34),
#  ('GRADUATE LORD', 156, 'G', 35),
#  ('OPERATION OPERATION', 156, 'G', 35),
#  ('GRAPES FURY', 155, 'G', 37),
#  ('SASSY PACKER', 154, 'G', 38),
#  ('CROSSROADS CASUALTIES', 153, 'G', 39),
#  ('SPOILERS HELLFIGHTERS', 151, 'G', 40),
#  ('SATURDAY LAMBS', 150, 'G', 41),
#  ('COLOR PHILADELPHIA', 149, 'G', 42),
#  ('BLANKET BEVERLY', 148, 'G', 43),
#  ('EASY GLADIATOR', 148, 'G', 43),
#  ('MENAGERIE RUSHMORE', 147, 'G', 45),
#  ('SCISSORHANDS SLUMS', 147, 'G', 45),
#  ('DANCING FEVER', 144, 'G', 47),
#  ('PACIFIC AMISTAD', 144, 'G', 47),
#  ('ENCINO ELF', 143, 'G', 49),
#  ('TRACY CIDER', 142, 'G', 50),
#  ('HOCUS FRIDA', 141, 'G', 51),
#  ('STRANGER STRANGERS', 139, 'G', 52),
#  ('TRAFFIC HOBBIT', 139, 'G', 52),
#  ('LIBERTY MAGNIFICENT', 138, 'G', 54),
#  ('GREASE YOUTH', 135, 'G', 55),
#  ('JAPANESE RUN', 135, 'G', 55),
#  ('DUDE BLINDNESS', 132, 'G', 57),
#  ('FANTASIA PARK', 131, 'G', 58),
#  ('AFRICAN EGG', 130, 'G', 59),
#  ('FARGO GANDHI', 130, 'G', 59),
#  ('BAREFOOT MANCHURIAN', 129, 'G', 61),
#  ('GOSFORD DONNIE', 129, 'G', 61),
#  ('WARS PLUTO', 128, 'G', 63),
#  ('ALAMO VIDEOTAPE', 126, 'G', 64),
#  ('SAINTS BRIDE', 125, 'G', 65),
#  ('SHINING ROSES', 125, 'G', 65),
#  ('CHISUM BEHAVIOR', 124, 'G', 67),
#  ('BREAKFAST GOLDFINGER', 123, 'G', 68),
#  ('BEACH HEARTBREAKERS', 122, 'G', 69),
#  ('DOGMA FAMILY', 122, 'G', 69),
#  ('EXTRAORDINARY CONQUERER', 122, 'G', 69),
#  ('JUMANJI BLADE', 121, 'G', 72),
#  ('DAZED PUNK', 120, 'G', 73),
#  ('BUGSY SONG', 119, 'G', 74),
#  ('FIDELITY DEVIL', 118, 'G', 75),
#  ('AFFAIR PREJUDICE', 117, 'G', 76),
#  ('CONNECTION MICROCOSMOS', 115, 'G', 77),
#  ('GILBERT PELICAN', 114, 'G', 78),
#  ('MARRIED GO', 114, 'G', 78),
#  ('DAY UNFAITHFUL', 113, 'G', 80),
#  ('CAT CONEHEADS', 112, 'G', 81),
#  ('JAWS HARRY', 112, 'G', 81),
#  ('WATERSHIP FRONTIER', 112, 'G', 81),
#  ('DRUMLINE CYCLONE', 110, 'G', 84),
#  ('SAMURAI LION', 110, 'G', 84),
#  ('TRAP GUYS', 110, 'G', 84),
#  ('SECRETS PARADISE', 109, 'G', 87),
#  ('AUTUMN CROW', 108, 'G', 88),
#  ('SWEETHEARTS SUSPECTS', 108, 'G', 88),
#  ('CHITTY LOCK', 107, 'G', 90),
#  ('DIARY PANIC', 107, 'G', 90),
#  ('SAGEBRUSH CLUELESS', 106, 'G', 92),
#  ('HUNGER ROOF', 105, 'G', 93),
#  ('MOB DUFFEL', 105, 'G', 93),
#  ('FIREHOUSE VIETNAM', 103, 'G', 95),
#  ('GLASS DYING', 103, 'G', 95),
#  ('HEAVYWEIGHTS BEAST', 102, 'G', 97),
#  ('PANIC CLUB', 102, 'G', 97),
#  ('ROCK INSTINCT', 102, 'G', 97),
#  ('DWARFS ALTER', 101, 'G', 100),
#  ('FLATLINERS KILLER', 100, 'G', 101),
#  ('GUN BONNIE', 100, 'G', 101),
#  ('HAPPINESS UNITED', 100, 'G', 101),
#  ('HYDE DOCTOR', 100, 'G', 101),
#  ('ARMAGEDDON LOST', 99, 'G', 105),
#  ('STONE FIRE', 94, 'G', 106),
#  ('GOLDFINGER SENSIBILITY', 93, 'G', 107),
#  ('HILLS NEIGHBORS', 93, 'G', 107),
#  ('PANKY SUBMARINE', 93, 'G', 107),
#  ('SUICIDES SILENCE', 93, 'G', 107),
#  ('TRUMAN CRAZY', 92, 'G', 111),
#  ('BUTTERFLY CHOCOLAT', 89, 'G', 112),
#  ('PULP BEVERLY', 89, 'G', 112),
#  ('CHEAPER CLYDE', 87, 'G', 114),
#  ('ANNIE IDENTITY', 86, 'G', 115),
#  ('MIDNIGHT WESTWARD', 86, 'G', 115),
#  ('AMISTAD MIDSUMMER', 85, 'G', 117),
#  ('CASABLANCA SUPER', 85, 'G', 117),
#  ('GHOST GROUNDHOG', 85, 'G', 117),
#  ('DAISY MENAGERIE', 84, 'G', 120),
#  ('WARLOCK WEREWOLF', 83, 'G', 121),
#  ('TYCOON GATHERING', 82, 'G', 122),
#  ('CLASH FREDDY', 81, 'G', 123),
#  ('DESPERATE TRAINSPOTTING', 81, 'G', 123),
#  ('GARDEN ISLAND', 80, 'G', 125),
#  ('MEET CHOCOLATE', 80, 'G', 125),
#  ('TURN STAR', 80, 'G', 125),
#  ('WAR NOTTING', 80, 'G', 125),
#  ('SPIKING ELEMENT', 79, 'G', 129),
#  ('WEREWOLF LOLA', 79, 'G', 129),
#  ('PICKUP DRIVING', 77, 'G', 131),
#  ('LOVER TRUMAN', 75, 'G', 132),
#  ('SATISFACTION CONFIDENTIAL', 75, 'G', 132),
#  ('ANGELS LIFE', 74, 'G', 134),
#  ('TEEN APOLLO', 74, 'G', 134),
#  ('REBEL AIRPORT', 73, 'G', 136),
#  ('VALLEY PACKER', 73, 'G', 136),
#  ('WAKE JAWS', 73, 'G', 136),
#  ('BLOOD ARGONAUTS', 71, 'G', 139),
#  ('COLDBLOODED DARLING', 70, 'G', 140),
#  ('CRUELTY UNFORGIVEN', 69, 'G', 141),
#  ('TIMBERLAND SKY', 69, 'G', 141),
#  ('LONELY ELEPHANT', 67, 'G', 143),
#  ('EVE RESURRECTION', 66, 'G', 144),
#  ('BARBARELLA STREETCAR', 65, 'G', 145),
#  ('NOVOCAINE FLIGHT', 64, 'G', 146),
#  ('SLEEPLESS MONSOON', 64, 'G', 146),
#  ('BONNIE HOLOCAUST', 63, 'G', 148),
#  ('BORROWERS BEDAZZLED', 63, 'G', 148),
#  ('BUNCH MINDS', 63, 'G', 148),
#  ('HANGING DEEP', 62, 'G', 151),
#  ('SNOWMAN ROLLERCOASTER', 62, 'G', 151),
#  ('UNBREAKABLE KARATE', 62, 'G', 151),
#  ('BIRDS PERDITION', 61, 'G', 154),
#  ('BULWORTH COMMANDMENTS', 61, 'G', 154),
#  ('WATERFRONT DELIVERANCE', 61, 'G', 154),
#  ('SMILE EARRING', 60, 'G', 157),
#  ('HEARTBREAKERS BRIGHT', 59, 'G', 158),
#  ('MINORITY KISS', 59, 'G', 158),
#  ('RINGS HEARTBREAKERS', 58, 'G', 160),
#  ('DOCTOR GRAIL', 57, 'G', 161),
#  ('MOSQUITO ARMAGEDDON', 57, 'G', 161),
#  ('NOON PAPI', 57, 'G', 161),
#  ('BRIDE INTRIGUE', 56, 'G', 164),
#  ('DESTINY SATURDAY', 56, 'G', 164),
#  ('KILL BROTHERHOOD', 54, 'G', 166),
#  ('PRIMARY GLASS', 53, 'G', 167),
#  ('SUMMER SCARFACE', 53, 'G', 167),
#  ('HARPER DYING', 52, 'G', 169),
#  ('LUST LOCK', 52, 'G', 169),
#  ('SIDE ARK', 52, 'G', 169),
#  ('EXCITEMENT EVE', 51, 'G', 172),
#  ('BLUES INSTINCT', 50, 'G', 173),
#  ('HOOK CHARIOTS', 49, 'G', 174),
#  ('ACE GOLDFINGER', 48, 'G', 175),
#  ('MIDSUMMER GROUNDHOG', 48, 'G', 175),
#  ('DIVORCE SHINING', 47, 'G', 177),
#  ('DOWNHILL ENOUGH', 47, 'G', 177),
#  ('WORST BANGER', 185, 'PG', 1),
#  ('MONSOON CAUSE', 182, 'PG', 2),
#  ('RECORDS ZORRO', 182, 'PG', 2),
#  ('STAR OPERATION', 181, 'PG', 4),
#  ('BORN SPINAL', 179, 'PG', 5),
#  ('MANCHURIAN CURTAIN', 177, 'PG', 6),
#  ('RIDER CADDYSHACK', 177, 'PG', 6),
#  ('CYCLONE FAMILY', 176, 'PG', 8),
#  ('GREEK EVERYONE', 176, 'PG', 8),
#  ('SWEDEN SHINING', 176, 'PG', 8),
#  ('PATTON INTERVIEW', 175, 'PG', 11),
#  ('SPLASH GUMP', 175, 'PG', 11),
#  ('GLADIATOR WESTWARD', 173, 'PG', 13),
#  ('TALENTED HOMICIDE', 173, 'PG', 13),
#  ('NORTHWEST POLISH', 172, 'PG', 15),
#  ('TRAMP OTHERS', 171, 'PG', 16),
#  ('TRADING PINOCCHIO', 170, 'PG', 17),
#  ('AGENT TRUMAN', 169, 'PG', 18),
#  ('KENTUCKIAN GIANT', 169, 'PG', 18),
#  ('DYING MAKER', 168, 'PG', 20),
#  ('MOTIONS DETAILS', 166, 'PG', 21),
#  ('MURDER ANTITRUST', 166, 'PG', 21),
#  ('EVERYONE CRAFT', 163, 'PG', 23),
#  ('QUEEN LUKE', 163, 'PG', 23),
#  ('BIRCH ANTITRUST', 162, 'PG', 25),
#  ('GABLES METROPOLIS', 161, 'PG', 26),
#  ('MASSAGE IMAGE', 161, 'PG', 26),
#  ('OLEANDER CLUE', 161, 'PG', 26),
#  ('STOCK GLASS', 160, 'PG', 29),
#  ('FOOL MOCKINGBIRD', 158, 'PG', 30),
#  ('SECRETARY ROUGE', 158, 'PG', 30),
#  ('MULHOLLAND BEAST', 157, 'PG', 32),
#  ('TOOTSIE PILOT', 157, 'PG', 32),
#  ('TADPOLE PARK', 155, 'PG', 34),
#  ('SANTA PARIS', 154, 'PG', 35),
#  ('CENTER DINOSAUR', 152, 'PG', 36),
#  ('TWISTED PIRATES', 152, 'PG', 36),
#  ('WAGON JAWS', 152, 'PG', 36),
#  ('CAROL TEXAS', 151, 'PG', 39),
#  ('ALI FOREVER', 150, 'PG', 40),
#  ('HYSTERICAL GRAIL', 150, 'PG', 40),
#  ('NIGHTMARE CHILL', 149, 'PG', 42),
#  ('FIREBALL PHILADELPHIA', 148, 'PG', 43),
#  ('TELEGRAPH VOYAGE', 148, 'PG', 43),
#  ('RANGE MOONWALKER', 147, 'PG', 45),
#  ('SLUMS DUCK', 147, 'PG', 45),
#  ('COWBOY DOOM', 146, 'PG', 47),
#  ('MOURNING PURPLE', 146, 'PG', 47),
#  ('PRESIDENT BANG', 144, 'PG', 49),
#  ('CHILL LUCK', 142, 'PG', 50),
#  ('FERRIS MOTHER', 142, 'PG', 50),
#  ('DISCIPLE MOTHER', 141, 'PG', 52),
#  ('LIAISONS SWEET', 140, 'PG', 53),
#  ('STEERS ARMAGEDDON', 140, 'PG', 53),
#  ('MAIDEN HOME', 138, 'PG', 55),
#  ('ARSENIC INDEPENDENCE', 137, 'PG', 56),
#  ('GRIT CLOCKWORK', 137, 'PG', 56),
#  ('POLLOCK DELIVERANCE', 137, 'PG', 56),
#  ('SLEEPY JAPANESE', 137, 'PG', 56),
#  ('ALASKA PHANTOM', 136, 'PG', 60),
#  ('BRINGING HYSTERICAL', 136, 'PG', 60),
#  ('CRAZY HOME', 136, 'PG', 60),
#  ('SQUAD FISH', 136, 'PG', 60),
#  ('DREAM PICKUP', 135, 'PG', 64),
#  ('MONEY HAROLD', 135, 'PG', 64),
#  ('WALLS ARTIST', 135, 'PG', 64),
#  ('BUCKET BROTHERHOOD', 133, 'PG', 67),
#  ('MALLRATS UNITED', 133, 'PG', 67),
#  ('NECKLACE OUTBREAK', 132, 'PG', 69),
#  ('SKY MIRACLE', 132, 'PG', 69),
#  ('VOLUME HOUSE', 132, 'PG', 69),
#  ('OPEN AFRICAN', 131, 'PG', 72),
#  ('MAJESTIC FLOATS', 130, 'PG', 73),
#  ('UNFORGIVEN ZOOLANDER', 129, 'PG', 74),
#  ('HOLES BRANNIGAN', 128, 'PG', 75),
#  ('JEDI BENEATH', 128, 'PG', 75),
#  ('PAPI NECKLACE', 128, 'PG', 75),
#  ('CHICKEN HELLFIGHTERS', 122, 'PG', 78),
#  ('MIGHTY LUCK', 122, 'PG', 78),
#  ('ARIZONA BANG', 121, 'PG', 80),
#  ('BRANNIGAN SUNRISE', 121, 'PG', 80),
#  ('DANGEROUS UPTOWN', 121, 'PG', 80),
#  ('JAWBREAKER BROOKLYN', 118, 'PG', 83),
#  ('OTHERS SOUP', 118, 'PG', 83),
#  ('PATHS CONTROL', 118, 'PG', 83),
#  ('GRAFFITI LOVE', 117, 'PG', 86),
#  ('MAGIC MALLRATS', 117, 'PG', 86),
#  ('RESURRECTION SILVERADO', 117, 'PG', 86),
#  ('INSTINCT AIRPORT', 116, 'PG', 89),
#  ('WORDS HUNTER', 116, 'PG', 89),
#  ('OSCAR GOLD', 115, 'PG', 91),
#  ('POTTER CONNECTICUT', 115, 'PG', 91),
#  ('CARRIE BUNCH', 114, 'PG', 93),
#  ('CHAINSAW UPTOWN', 114, 'PG', 93),
#  ('CHASING FIGHT', 114, 'PG', 93),
#  ('SUGAR WONKA', 114, 'PG', 93),
#  ('SUPERFLY TRIP', 114, 'PG', 93),
#  ('AMADEUS HOLY', 113, 'PG', 98),
#  ('LEGALLY SECRETARY', 113, 'PG', 98),
#  ('WONDERLAND CHRISTMAS', 111, 'PG', 100),
#  ('SNATCH SLIPPER', 110, 'PG', 101),
#  ('EFFECT GLADIATOR', 107, 'PG', 102),
#  ('HATE HANDICAP', 107, 'PG', 102),
#  ('MONSTER SPARTACUS', 107, 'PG', 102),
#  ('PARTY KNOCK', 107, 'PG', 102),
#  ('DALMATIONS SWEDEN', 106, 'PG', 106),
#  ('GASLIGHT CRUSADE', 106, 'PG', 106),
#  ('PRIVATE DROP', 106, 'PG', 106),
#  ('WON DARES', 105, 'PG', 109),
#  ('CROW GREASE', 104, 'PG', 110),
#  ('PINOCCHIO SIMON', 103, 'PG', 111),
#  ('BOILED DARES', 102, 'PG', 112),
#  ('CIDER DESIRE', 101, 'PG', 113),
#  ('BEHAVIOR RUNAWAY', 100, 'PG', 114),
#  ('PIRATES ROXANNE', 100, 'PG', 114),
#  ('PUNK DIVORCE', 100, 'PG', 114),
#  ('FRENCH HOLIDAY', 99, 'PG', 117),
#  ('PET HAUNTING', 99, 'PG', 117),
#  ('SABRINA MIDNIGHT', 99, 'PG', 117),
#  ('BOUND CHEAPER', 98, 'PG', 120),
#  ('SENSIBILITY REAR', 98, 'PG', 120),
#  ('EXPENDABLE STALLION', 97, 'PG', 122),
#  ('INVASION CYCLONE', 97, 'PG', 122),
#  ('DRUMS DYNAMITE', 96, 'PG', 124),
#  ('HORN WORKING', 95, 'PG', 125),
#  ('FULL FLATLINERS', 94, 'PG', 126),
#  ('BILL OTHERS', 93, 'PG', 127),
#  ('SHANE DARKNESS', 93, 'PG', 127),
#  ('OPPOSITE NECKLACE', 92, 'PG', 129),
#  ('FATAL HAUNTED', 91, 'PG', 130),
#  ('TITANS JERK', 91, 'PG', 130),
#  ('SECRET GROUNDHOG', 90, 'PG', 132),
#  ('TREATMENT JEKYLL', 87, 'PG', 133),
#  ('ACADEMY DINOSAUR', 86, 'PG', 134),
#  ('BLACKOUT PRIVATE', 85, 'PG', 135),
#  ('EGYPT TENENBAUMS', 85, 'PG', 135),
#  ('LOLA AGENT', 85, 'PG', 135),
#  ('STAGE WORLD', 85, 'PG', 135),
#  ('WASTELAND DIVINE', 85, 'PG', 135),
#  ('UPTOWN YOUNG', 84, 'PG', 140),
#  ('MOON BUNCH', 83, 'PG', 141),
#  ('FROST HEAD', 82, 'PG', 142),
#  ('LOSER HUSTLER', 80, 'PG', 143),
#  ('PEAK FOREVER', 80, 'PG', 143),
#  ('SEA VIRGIN', 80, 'PG', 143),
#  ('SHAWSHANK BUBBLE', 80, 'PG', 143),
#  ('WATCH TRACY', 78, 'PG', 147),
#  ('HELLFIGHTERS SIERRA', 75, 'PG', 148),
#  ('NEWTON LABYRINTH', 75, 'PG', 148),
#  ('WIZARD COLDBLOODED', 75, 'PG', 148),
#  ('MODERN DORADO', 74, 'PG', 151),
#  ('RAINBOW SHOCK', 74, 'PG', 151),
#  ('SILVERADO GOLDFINGER', 74, 'PG', 151),
#  ('BEDAZZLED MARRIED', 73, 'PG', 154),
#  ('MUSKETEERS WAIT', 73, 'PG', 154),
#  ('FICTION CHRISTMAS', 72, 'PG', 156),
#  ('TEMPLE ATTRACTION', 71, 'PG', 157),
#  ('WEDDING APOLLO', 70, 'PG', 158),
#  ('HOLLYWOOD ANONYMOUS', 69, 'PG', 159),
#  ('TOMATOES HELLFIGHTERS', 68, 'PG', 160),
#  ('EGG IGBY', 67, 'PG', 161),
#  ('LADY STAGE', 67, 'PG', 161),
#  ('CHARADE DUFFEL', 66, 'PG', 163),
#  ('LOVELY JINGLE', 65, 'PG', 164),
#  ('PATRIOT ROMAN', 65, 'PG', 164),
#  ('MILE MULAN', 64, 'PG', 166),
#  ('CHINATOWN GLADIATOR', 61, 'PG', 167),
#  ('POLISH BROOKLYN', 61, 'PG', 167),
#  ('TROUBLE DATE', 61, 'PG', 167),
#  ('JERSEY SASSY', 60, 'PG', 170),
#  ('MOCKINGBIRD HOLLYWOOD', 60, 'PG', 170),
#  ('ROOM ROMAN', 60, 'PG', 170),
#  ('LEGEND JEDI', 59, 'PG', 173),
#  ('JEKYLL FROGMEN', 58, 'PG', 174),
#  ('OKLAHOMA JUMANJI', 58, 'PG', 174),
#  ('SUPER WYOMING', 58, 'PG', 174),
#  ('DAWN POND', 57, 'PG', 177),
#  ('GOODFELLAS SALUTE', 56, 'PG', 178),
#  ('COAST RAINBOW', 55, 'PG', 179),
#  ('MOVIE SHAKESPEARE', 53, 'PG', 180),
#  ('TEQUILA PAST', 53, 'PG', 180),
#  ('TROJAN TOMORROW', 52, 'PG', 182),
#  ('CHAMPION FLATLINERS', 51, 'PG', 183),
#  ('FRISCO FORREST', 51, 'PG', 183),
#  ('LION UNCUT', 50, 'PG', 185),
#  ('MUPPET MILE', 50, 'PG', 185),
#  ('PILOT HOOSIERS', 50, 'PG', 185),
#  ('HURRICANE AFFAIR', 49, 'PG', 188),
#  ('HEAVEN FREEDOM', 48, 'PG', 189),
#  ('PELICAN COMFORTS', 48, 'PG', 189),
#  ('RUSH GOODFELLAS', 48, 'PG', 189),
#  ('SHANGHAI TYCOON', 47, 'PG', 192),
#  ('SUSPECTS QUILLS', 47, 'PG', 192),
#  ('IRON MOON', 46, 'PG', 194),
#  ('CHICAGO NORTH', 185, 'PG-13', 1),
#  ('GANGS PRIDE', 185, 'PG-13', 1),
#  ('POND SEATTLE', 185, 'PG-13', 1),
#  ('CONSPIRACY SPIRIT', 184, 'PG-13', 4),
#  ('THEORY MERMAID', 184, 'PG-13', 4),
#  ('FRONTIER CABIN', 183, 'PG-13', 6),
#  ('REDS POCUS', 182, 'PG-13', 7),
#  ('HOTEL HAPPINESS', 181, 'PG-13', 8),
#  ('JACKET FRISCO', 181, 'PG-13', 8),
#  ('IMPACT ALADDIN', 180, 'PG-13', 10),
#  ('MIXED DOORS', 180, 'PG-13', 10),
#  ('NASH CHOCOLAT', 180, 'PG-13', 10),
#  ('KICK SAVANNAH', 179, 'PG-13', 13),
#  ('VIRGIN DAISY', 179, 'PG-13', 13),
#  ('FURY MURDER', 178, 'PG-13', 15),
#  ('IMAGE PRINCESS', 178, 'PG-13', 15),
#  ('INNOCENT USUAL', 178, 'PG-13', 15),
#  ('MADNESS ATTACKS', 178, 'PG-13', 15),
#  ('NAME DETECTIVE', 178, 'PG-13', 15),
#  ('ROCKETEER MOTHER', 178, 'PG-13', 15),
#  ('WRONG BEHAVIOR', 178, 'PG-13', 15),
#  ('BRAVEHEART HUMAN', 176, 'PG-13', 22),
#  ('GATHERING CALENDAR', 176, 'PG-13', 22),
#  ('EVOLUTION ALTER', 174, 'PG-13', 24),
#  ('VIETNAM SMOOCHY', 174, 'PG-13', 24),
#  ('EYES DRIVING', 172, 'PG-13', 26),
#  ('IDAHO LOVE', 172, 'PG-13', 26),
#  ('UNCUT SUICIDES', 172, 'PG-13', 26),
#  ('MAGNOLIA FORRESTER', 171, 'PG-13', 29),
#  ('MOONSHINE CABIN', 171, 'PG-13', 29),
#  ('WORLD LEATHERNECKS', 171, 'PG-13', 29),
#  ('BREAKING HOME', 169, 'PG-13', 32),
#  ('TRANSLATION SUMMER', 168, 'PG-13', 33),
#  ('SHOW LORD', 167, 'PG-13', 34),
#  ('CONTACT ANONYMOUS', 166, 'PG-13', 35),
#  ('MINE TITANS', 166, 'PG-13', 35),
#  ('DARLING BREAKING', 165, 'PG-13', 37),
#  ('SONG HEDWIG', 165, 'PG-13', 37),
#  ('SPEAKEASY DATE', 165, 'PG-13', 37),
#  ('MISSION ZOOLANDER', 164, 'PG-13', 40),
#  ('CASPER DRAGONFLY', 163, 'PG-13', 41),
#  ('KISS GLORY', 163, 'PG-13', 41),
#  ('LOVERBOY ATTACKS', 162, 'PG-13', 43),
#  ('MIRACLE VIRTUAL', 162, 'PG-13', 43),
#  ('ROSES TREASURE', 162, 'PG-13', 43),
#  ('METAL ARMAGEDDON', 161, 'PG-13', 46),
#  ('PEACH INNOCENT', 160, 'PG-13', 47),
#  ('DRIVER ANNIE', 159, 'PG-13', 48),
#  ('POSEIDON FOREVER', 159, 'PG-13', 48),
#  ('HOBBIT ALIEN', 157, 'PG-13', 50),
#  ('PAST SUICIDES', 157, 'PG-13', 50),
#  ('SLIPPER FIDELITY', 156, 'PG-13', 52),
#  ('PSYCHO SHRUNK', 155, 'PG-13', 53),
#  ('SHREK LICENSE', 154, 'PG-13', 54),
#  ('APOLLO TEEN', 153, 'PG-13', 55),
#  ('LEATHERNECKS DWARFS', 153, 'PG-13', 55),
#  ('RIGHT CRANES', 153, 'PG-13', 55),
#  ('ROLLERCOASTER BRINGING', 153, 'PG-13', 55),
#  ('SISTER FREDDY', 152, 'PG-13', 59),
#  ('TELEMARK HEARTBREAKERS', 152, 'PG-13', 59),
#  ('TOURIST PELICAN', 152, 'PG-13', 59),
#  ('BEETHOVEN EXORCIST', 151, 'PG-13', 62),
#  ('HUNCHBACK IMPOSSIBLE', 151, 'PG-13', 62),
#  ('MASKED BUBBLE', 151, 'PG-13', 62),
#  ('SCHOOL JACKET', 151, 'PG-13', 62),
#  ('BINGO TALENTED', 150, 'PG-13', 66),
#  ('CLEOPATRA DEVIL', 150, 'PG-13', 66),
#  ('RUSHMORE MERMAID', 150, 'PG-13', 66),
#  ('MINDS TRUMAN', 149, 'PG-13', 69),
#  ('RIVER OUTLAW', 149, 'PG-13', 69),
#  ('FLINTSTONES HAPPINESS', 148, 'PG-13', 71),
#  ('OUTLAW HANKY', 148, 'PG-13', 71),
#  ('ARACHNOPHOBIA ROLLERCOASTER', 147, 'PG-13', 73),
#  ('HALF OUTFIELD', 146, 'PG-13', 74),
#  ('FLOATS GARDEN', 145, 'PG-13', 75),
#  ('PAYCHECK WAIT', 145, 'PG-13', 75),
#  ('ROCKY WAR', 145, 'PG-13', 75),
#  ('FACTORY DRAGON', 144, 'PG-13', 78),
#  ('LAMBS CINCINATTI', 144, 'PG-13', 78),
#  ('STRICTLY SCARFACE', 144, 'PG-13', 78),
#  ('CLOCKWORK PARADISE', 143, 'PG-13', 81),
#  ('CROOKED FROGMEN', 143, 'PG-13', 81),
#  ('DETECTIVE VISION', 143, 'PG-13', 81),
#  ('MILLION ACE', 142, 'PG-13', 84),
#  ('DYNAMITE TARZAN', 141, 'PG-13', 85),
#  ('HOMICIDE PEACH', 141, 'PG-13', 85),
#  ('CLYDE THEORY', 139, 'PG-13', 87),
#  ('GROUNDHOG UNCUT', 139, 'PG-13', 87),
#  ('VOICE PEACH', 139, 'PG-13', 87),
#  ('EXPECATIONS NATURAL', 138, 'PG-13', 90),
#  ('SPINAL ROCKY', 138, 'PG-13', 90),
#  ('SPIRITED CASUALTIES', 138, 'PG-13', 90),
#  ('PHILADELPHIA WIFE', 137, 'PG-13', 93),
#  ('MAKER GABLES', 136, 'PG-13', 94),
#  ('REAP UNFAITHFUL', 136, 'PG-13', 94),
#  ('SUNRISE LEAGUE', 135, 'PG-13', 96),
#  ('THIEF PELICAN', 135, 'PG-13', 96),
#  ('PITTSBURGH HUNCHBACK', 134, 'PG-13', 98),
#  ('CURTAIN VIDEOTAPE', 133, 'PG-13', 99),
#  ('FREEDOM CLEOPATRA', 133, 'PG-13', 99),
#  ('PLATOON INSTINCT', 132, 'PG-13', 101),
#  ('STREAK RIDGEMONT', 132, 'PG-13', 101),
#  ('TRAINSPOTTING STRANGERS', 132, 'PG-13', 101),
#  ('STALLION SUNDANCE', 130, 'PG-13', 104),
#  ('SLEEPING SUSPECTS', 129, 'PG-13', 105),
#  ('USUAL UNTOUCHABLES', 128, 'PG-13', 106),
#  ('ARGONAUTS TOWN', 127, 'PG-13', 107),
#  ('GUNFIGHTER MUSSOLINI', 127, 'PG-13', 107),
#  ('MALTESE HOPE', 127, 'PG-13', 107),
#  ('ELEPHANT TROJAN', 126, 'PG-13', 110),
#  ('SINNERS ATLANTIS', 126, 'PG-13', 110),
#  ('HUNTER ALTER', 125, 'PG-13', 112),
#  ('JINGLE SAGEBRUSH', 124, 'PG-13', 113),
#  ('SPEED SUIT', 124, 'PG-13', 113),
#  ('SWARM GOLD', 123, 'PG-13', 115),
#  ('CONFUSED CANDLES', 122, 'PG-13', 116),
#  ('HARRY IDAHO', 121, 'PG-13', 117),
#  ('PARIS WEEKEND', 121, 'PG-13', 117),
#  ('COMMAND DARLING', 120, 'PG-13', 119),
#  ('DOLLS RAGE', 120, 'PG-13', 119),
#  ('KARATE MOON', 120, 'PG-13', 119),
#  ('ORDER BETRAYED', 120, 'PG-13', 119),
#  ('GAMES BOWFINGER', 119, 'PG-13', 123),
#  ('IDENTITY LOVER', 119, 'PG-13', 123),
#  ('BACKLASH UNDEFEATED', 118, 'PG-13', 125),
#  ('PERSONAL LADYBUGS', 118, 'PG-13', 125),
#  ('GLORY TRACY', 115, 'PG-13', 127),
#  ('ALABAMA DEVIL', 114, 'PG-13', 128),
#  ('BLADE POLISH', 114, 'PG-13', 128),
#  ('ATTACKS HATE', 113, 'PG-13', 130),
#  ('SPY MILE', 112, 'PG-13', 131),
#  ('WAIT CIDER', 112, 'PG-13', 131),
#  ('CELEBRITY HORN', 110, 'PG-13', 133),
#  ('LEAGUE HELLFIGHTERS', 110, 'PG-13', 133),
#  ('SEATTLE EXPECATIONS', 110, 'PG-13', 133),
#  ('PARK CITIZEN', 109, 'PG-13', 136),
#  ('RUGRATS SHAKESPEARE', 109, 'PG-13', 136),
#  ('WHALE BIKINI', 109, 'PG-13', 136),
#  ('LORD ARIZONA', 108, 'PG-13', 139),
#  ('INTENTIONS EMPIRE', 107, 'PG-13', 140),
#  ('UNDEFEATED DALMATIONS', 107, 'PG-13', 140),
#  ('WANDA CHAMBER', 107, 'PG-13', 140),
#  ('MICROCOSMOS PARADISE', 105, 'PG-13', 143),
#  ('FEATHERS METAL', 104, 'PG-13', 144),
#  ('BLINDNESS GUN', 103, 'PG-13', 145),
#  ('FALCON VOLUME', 102, 'PG-13', 146),
#  ('ROBBERS JOON', 102, 'PG-13', 146),
#  ('SCARFACE BANG', 102, 'PG-13', 146),
#  ('TREASURE COMMAND', 102, 'PG-13', 146),
#  ('BILKO ANONYMOUS', 100, 'PG-13', 150),
#  ('WYOMING STORM', 100, 'PG-13', 150),
#  ('TENENBAUMS COMMAND', 99, 'PG-13', 152),
#  ('LOST BIRD', 98, 'PG-13', 153),
#  ('MADRE GABLES', 98, 'PG-13', 153),
#  ('PREJUDICE OLEANDER', 98, 'PG-13', 153),
#  ('LUCKY FLYING', 97, 'PG-13', 156),
#  ('CORE SUIT', 92, 'PG-13', 157),
#  ('ANTHEM LUKE', 91, 'PG-13', 158),
#  ('TARZAN VIDEOTAPE', 91, 'PG-13', 158),
#  ('BASIC EASY', 90, 'PG-13', 160),
#  ('CIRCUS YOUTH', 90, 'PG-13', 160),
#  ('DARES PLUTO', 89, 'PG-13', 162),
#  ('ROOTS REMEMBER', 89, 'PG-13', 162),
#  ('CONGENIALITY QUEST', 87, 'PG-13', 164),
#  ('GANDHI KWAI', 86, 'PG-13', 165),
#  ('PACKER MADIGAN', 84, 'PG-13', 166),
#  ('SAVANNAH TOWN', 84, 'PG-13', 166),
#  ('ATTRACTION NEWTON', 83, 'PG-13', 168),
#  ('PERFECT GROOVE', 82, 'PG-13', 169),
#  ('RAIDERS ANTITRUST', 82, 'PG-13', 169),
#  ('REIGN GENTLEMEN', 82, 'PG-13', 169),
#  ('FLAMINGOS CONNECTICUT', 80, 'PG-13', 172),
#  ('SADDLE ANTITRUST', 80, 'PG-13', 172),
#  ('MOULIN WAKE', 79, 'PG-13', 174),
#  ('SHOCK CABIN', 79, 'PG-13', 174),
#  ('HOLIDAY GAMES', 78, 'PG-13', 176),
#  ('VOYAGE LEGALLY', 78, 'PG-13', 176),
#  ('BERETS AGENT', 77, 'PG-13', 178),
#  ('DESTINATION JERK', 76, 'PG-13', 179),
#  ('ORANGE GRAPES', 76, 'PG-13', 179),
#  ('VILLAIN DESPERATE', 76, 'PG-13', 179),
#  ('NETWORK PEAK', 75, 'PG-13', 182),
#  ('SNATCHERS MONTEZUMA', 74, 'PG-13', 183),
#  ('BRIGHT ENCOUNTERS', 73, 'PG-13', 184),
#  ('KNOCK WARLOCK', 71, 'PG-13', 185),
#  ('MANNEQUIN WORST', 71, 'PG-13', 185),
#  ('LOUISIANA HARRY', 70, 'PG-13', 187),
#  ('LEBOWSKI SOLDIERS', 69, 'PG-13', 188),
#  ('DIVIDE MONSTER', 68, 'PG-13', 189),
#  ('BUTCH PANTHER', 67, 'PG-13', 190),
#  ('SHOOTIST SUPERFLY', 67, 'PG-13', 190),
#  ('CLUB GRAFFITI', 65, 'PG-13', 192),
#  ('CONFESSIONS MAGUIRE', 65, 'PG-13', 192),
#  ('METROPOLIS COMA', 64, 'PG-13', 194),
#  ('TAXI KICK', 64, 'PG-13', 194),
#  ('TRIP NEWTON', 64, 'PG-13', 194),
#  ('VICTORY ACADEMY', 64, 'PG-13', 194),
#  ('INTOLERABLE INTENTIONS', 63, 'PG-13', 198),
#  ('AIRPLANE SIERRA', 62, 'PG-13', 199),
#  ('DRIFTER COMMANDMENTS', 61, 'PG-13', 200),
#  ('RESERVOIR ADAPTATION', 61, 'PG-13', 200),
#  ('SHAKESPEARE SADDLE', 60, 'PG-13', 202),
#  ('DAUGHTER MADIGAN', 59, 'PG-13', 203),
#  ('VISION TORQUE', 59, 'PG-13', 203),
#  ('WHISPERER GIANT', 59, 'PG-13', 203),
#  ('FANTASY TROOPERS', 58, 'PG-13', 206),
#  ('ALTER VICTORY', 57, 'PG-13', 207),
#  ('MATRIX SNOWMAN', 56, 'PG-13', 208),
#  ('JUGGLER HARDLY', 54, 'PG-13', 209),
#  ('OCTOBER SUBMARINE', 54, 'PG-13', 209),
#  ('THIN SAGEBRUSH', 53, 'PG-13', 211),
#  ('DEEP CRUSADE', 51, 'PG-13', 212),
#  ('ENGLISH BULWORTH', 51, 'PG-13', 212),
#  ('NATURAL STOCK', 50, 'PG-13', 214),
#  ('SMOKING BARBARELLA', 50, 'PG-13', 214),
#  ('NOTTING SPEAKEASY', 48, 'PG-13', 216),
#  ('PARADISE SABRINA', 48, 'PG-13', 216),
#  ('VALENTINE VANISHING', 48, 'PG-13', 216),
#  ('HALLOWEEN NUTS', 47, 'PG-13', 219),
#  ('HAWK CHILL', 47, 'PG-13', 219),
#  ('KWAI HOMEWARD', 46, 'PG-13', 221),
#  ('LABYRINTH LEAGUE', 46, 'PG-13', 221),
#  ('RIDGEMONT SUBMARINE', 46, 'PG-13', 221),
#  ('HOME PITY', 185, 'R', 1),
#  ('SOLDIERS EVOLUTION', 185, 'R', 1),
#  ('SWEET BROTHERHOOD', 185, 'R', 1),
#  ('SMOOCHY CONTROL', 184, 'R', 4),
#  ('SATURN NAME', 182, 'R', 5),
#  ('ANALYZE HOOSIERS', 181, 'R', 6),
#  ('HAUNTING PIANIST', 181, 'R', 6),
#  ('LOVE SUICIDES', 181, 'R', 6),
#  ('WILD APOLLO', 181, 'R', 6),
#  ('CAUSE DATE', 179, 'R', 10),
#  ('FLIGHT LIES', 179, 'R', 10),
#  ('SLACKER LIAISONS', 179, 'R', 10),
#  ('DROP WATERFRONT', 178, 'R', 13),
#  ('EXPRESS LONELY', 178, 'R', 13),
#  ('DOUBLE WRATH', 177, 'R', 15),
#  ('QUEST MUSSOLINI', 177, 'R', 15),
#  ('ENTRAPMENT SATISFACTION', 176, 'R', 17),
#  ('LIGHTS DEER', 174, 'R', 18),
#  ('FIRE WOLVES', 173, 'R', 19),
#  ('VELVET TERMINATOR', 173, 'R', 19),
#  ('CONNECTICUT TRAMP', 172, 'R', 21),
#  ('TIGHTS DAWN', 172, 'R', 21),
#  ('KRAMER CHOCOLATE', 171, 'R', 23),
#  ('ROXANNE REBEL', 171, 'R', 23),
#  ('SOUP WISDOM', 169, 'R', 25),
#  ('CAMPUS REMEMBER', 167, 'R', 26),
#  ('ESCAPE METROPOLIS', 167, 'R', 26),
#  ('REQUIEM TYCOON', 167, 'R', 26),
#  ('GREEDY ROOTS', 166, 'R', 29),
#  ('MASSACRE USUAL', 165, 'R', 30),
#  ('UNITED PILOT', 164, 'R', 31),
#  ('VIRGINIAN PLUTO', 164, 'R', 31),
#  ('GILMORE BOILED', 163, 'R', 33),
#  ('STORY SIDE', 163, 'R', 33),
#  ('BADMAN DAWN', 162, 'R', 35),
#  ('BROOKLYN DESERT', 161, 'R', 36),
#  ('KILLER INNOCENT', 161, 'R', 36),
#  ('NEIGHBORS CHARADE', 161, 'R', 36),
#  ('WASH HEAVENLY', 161, 'R', 36),
#  ('BEAR GRACELAND', 160, 'R', 40),
#  ('FEVER EMPIRE', 158, 'R', 41),
#  ('ROAD ROXANNE', 158, 'R', 41),
#  ('FINDING ANACONDA', 156, 'R', 43),
#  ('FAMILY SWEET', 155, 'R', 44),
#  ('DOUBTFIRE LABYRINTH', 154, 'R', 45),
#  ('DURHAM PANKY', 154, 'R', 45),
#  ('GOLD RIVER', 154, 'R', 45),
#  ('RAGING AIRPLANE', 154, 'R', 45),
#  ('GOLDMINE TYCOON', 153, 'R', 49),
#  ('RULES HUMAN', 153, 'R', 49),
#  ('TUXEDO MILE', 152, 'R', 51),
#  ('STRAIGHT HOURS', 151, 'R', 52),
#  ('GRINCH MASSAGE', 150, 'R', 53),
#  ('HOLOCAUST HIGHBALL', 149, 'R', 54),
#  ('SPIRIT FLINTSTONES', 149, 'R', 54),
#  ('ARMY FLINTSTONES', 148, 'R', 56),
#  ('MADISON TRAP', 147, 'R', 57),
#  ('HAMLET WISDOM', 146, 'R', 58),
#  ('RUN PACIFIC', 145, 'R', 59),
#  ('VACATION BOONDOCK', 145, 'R', 59),
#  ('SOUTH WAIT', 143, 'R', 61),
#  ('TOMORROW HUSTLER', 142, 'R', 62),
#  ('VANISHED GARDEN', 142, 'R', 62),
#  ('KISSING DOLLS', 141, 'R', 64),
#  ('SUN CONFESSIONS', 141, 'R', 64),
#  ('GRACELAND DYNAMITE', 140, 'R', 66),
#  ('LOATHING LEGALLY', 140, 'R', 66),
#  ('HORROR REIGN', 139, 'R', 68),
#  ('SHRUNK DIVINE', 139, 'R', 68),
#  ('WORKER TARZAN', 139, 'R', 68),
#  ('LOSE INCH', 137, 'R', 71),
#  ('WILLOW TRACY', 137, 'R', 71),
#  ('TOWN ARK', 136, 'R', 73),
#  ('ROBBERY BRIGHT', 134, 'R', 74),
#  ('SPLENDOR PATTON', 134, 'R', 74),
#  ('WEEKEND PERSONAL', 134, 'R', 74),
#  ('CHOCOLATE DUCK', 132, 'R', 77),
#  ('ICE CROSSING', 131, 'R', 78),
#  ('AMERICAN CIRCUS', 129, 'R', 79),
#  ('MUSIC BOONDOCK', 129, 'R', 79),
#  ('GALAXY SWEETHEARTS', 128, 'R', 81),
#  ('SEVEN SWARM', 127, 'R', 82),
#  ('SUBMARINE BED', 127, 'R', 82),
#  ('FREAKY POCUS', 126, 'R', 84),
#  ('PAJAMA JAWBREAKER', 126, 'R', 84),
#  ('WOMEN DORADO', 126, 'R', 84),
#  ('FISH OPUS', 125, 'R', 87),
#  ('CLONES PINOCCHIO', 124, 'R', 88),
#  ('ILLUSION AMELIE', 122, 'R', 89),
#  ('BOOGIE AMELIE', 121, 'R', 90),
#  ('LOCK REAR', 120, 'R', 91),
#  ('RAGE GAMES', 120, 'R', 91),
#  ('APOCALYPSE FLAMINGOS', 119, 'R', 93),
#  ('STRANGERS GRAFFITI', 119, 'R', 93),
#  ('ORIENT CLOSER', 118, 'R', 95),
#  ('MADIGAN DORADO', 116, 'R', 96),
#  ('PRIX UNDEFEATED', 115, 'R', 97),
#  ('TROOPERS METAL', 115, 'R', 97),
#  ('BANGER PINOCCHIO', 113, 'R', 99),
#  ('SHEPHERD MIDSUMMER', 113, 'R', 99),
#  ('CONVERSATION DOWNHILL', 112, 'R', 101),
#  ('CROWDS TELEMARK', 112, 'R', 101),
#  ('CRUSADE HONEY', 112, 'R', 101),
#  ('QUILLS BULL', 112, 'R', 101),
#  ('STAGECOACH ARMAGEDDON', 112, 'R', 101),
#  ('FROGMEN BREAKING', 111, 'R', 106),
#  ('SIEGE MADRE', 111, 'R', 106),
#  ('SUIT WALLS', 111, 'R', 106),
#  ('TIES HUNGER', 111, 'R', 106),
#  ('WIND PHANTOM', 111, 'R', 106),
#  ('HIGHBALL POTTER', 110, 'R', 111),
#  ('REMEMBER DIARY', 110, 'R', 111),
#  ('HOUSE DYNAMITE', 109, 'R', 113),
#  ('GORGEOUS BINGO', 108, 'R', 114),
#  ('HANDICAP BOONDOCK', 108, 'R', 114),
#  ('DATE SPEED', 104, 'R', 116),
#  ('SHIP WONDERLAND', 104, 'R', 116),
#  ('TITANIC BOONDOCK', 104, 'R', 116),
#  ('HOMEWARD CIDER', 103, 'R', 119),
#  ('MOTHER OLEANDER', 103, 'R', 119),
#  ('GIANT TROOPERS', 102, 'R', 121),
#  ('JEOPARDY ENCINO', 102, 'R', 121),
#  ('OPUS ICE', 102, 'R', 121),
#  ('GHOSTBUSTERS ELF', 101, 'R', 124),
#  ('ROOF CHAMPION', 101, 'R', 124),
#  ('ZOOLANDER FICTION', 101, 'R', 124),
#  ('DELIVERANCE MULHOLLAND', 100, 'R', 127),
#  ('DIVINE RESURRECTION', 100, 'R', 127),
#  ('EARRING INSTINCT', 98, 'R', 129),
#  ('FEUD FROGMEN', 98, 'R', 129),
#  ('WISDOM WORKER', 98, 'R', 129),
#  ('CLUELESS BUCKET', 95, 'R', 132),
#  ('DISTURBING SCARFACE', 94, 'R', 133),
#  ('ANACONDA CONFESSIONS', 92, 'R', 134),
#  ('KANE EXORCIST', 92, 'R', 134),
#  ('FIGHT JAWBREAKER', 91, 'R', 136),
#  ('VERTIGO NORTHWEST', 90, 'R', 137),
#  ('BEAST HUNCHBACK', 89, 'R', 138),
#  ('DETAILS PACKER', 88, 'R', 139),
#  ('HOLY TADPOLE', 88, 'R', 139),
#  ('PURPLE MOVIE', 88, 'R', 139),
#  ('TERMINATOR CLUB', 88, 'R', 139),
#  ('DEVIL DESIRE', 87, 'R', 143),
#  ('YENTL IDAHO', 86, 'R', 144),
#  ('BEVERLY OUTLAW', 85, 'R', 145),
#  ('CANYON STOCK', 85, 'R', 145),
#  ('OZ LIAISONS', 85, 'R', 145),
#  ('WINDOW SIDE', 85, 'R', 145),
#  ('GONE TROUBLE', 84, 'R', 149),
#  ('GUYS FALCON', 84, 'R', 149),
#  ('HIGH ENCINO', 84, 'R', 149),
#  ('HONEY TIES', 84, 'R', 149),
#  ('JEEPERS WEDDING', 84, 'R', 149),
#  ('PLUTO OLEANDER', 84, 'R', 149),
#  ('SLING LUKE', 84, 'R', 149),
#  ('FUGITIVE MAGUIRE', 83, 'R', 156),
#  ('ALONE TRIP', 82, 'R', 157),
#  ('ANYTHING SAVANNAH', 82, 'R', 157),
#  ('AMELIE HELLFIGHTERS', 79, 'R', 159),
#  ('ISHTAR ROCKETEER', 79, 'R', 159),
#  ('UNFAITHFUL KILL', 78, 'R', 161),
#  ('FIDDLER LOST', 75, 'R', 162),
#  ('STAMPEDE DISTURBING', 75, 'R', 162),
#  ('WORKING MICROCOSMOS', 74, 'R', 164),
#  ('BROTHERHOOD BLANKET', 73, 'R', 165),
#  ('FRIDA SLIPPER', 73, 'R', 165),
#  ('SALUTE APOLLO', 73, 'R', 165),
#  ('STREETCAR INTENTIONS', 73, 'R', 165),
#  ('HARDLY ROBBERS', 72, 'R', 169),
#  ('MAUDE MOD', 72, 'R', 169),
#  ('CHARIOTS CONSPIRACY', 71, 'R', 171),
#  ('TRAIN BUNCH', 71, 'R', 171),
#  ('CANDIDATE PERDITION', 70, 'R', 173),
#  ('CHANCE RESURRECTION', 70, 'R', 173),
#  ('HEAD STRANGER', 69, 'R', 175),
#  ('DOOM DANCING', 68, 'R', 176),
#  ('COMANCHEROS ENEMY', 67, 'R', 177),
#  ('SILENCE KANE', 67, 'R', 177),
#  ('DESERT POSEIDON', 64, 'R', 179),
#  ('BOULEVARD MOB', 63, 'R', 180),
#  ('DINOSAUR SECRETARY', 63, 'R', 180),
#  ('FORREST SONS', 63, 'R', 180),
#  ('REUNION WITCHES', 63, 'R', 180),
#  ('BUBBLE GROSSE', 60, 'R', 184),
#  ('COMMANDMENTS EXPRESS', 59, 'R', 185),
#  ('INTERVIEW LIAISONS', 59, 'R', 185),
#  ('JET NEIGHBORS', 59, 'R', 185),
#  ('CLOSER BANG', 58, 'R', 188),
#  ('CUPBOARD SINNERS', 56, 'R', 189),
#  ('AIRPORT POLLOCK', 54, 'R', 190),
#  ('GO PURPLE', 54, 'R', 190),
#  ('SENSE GREEK', 54, 'R', 190),
#  ('MAGNIFICENT CHITTY', 53, 'R', 193),
#  ('CROSSING DIVORCE', 50, 'R', 194),
#  ('GROSSE WONDERFUL', 49, 'R', 195),
#  ('CRYSTAL BREAKING', 184, 'NC-17', 1),
#  ('KING EVOLUTION', 184, 'NC-17', 1),
#  ('SONS INTERVIEW', 184, 'NC-17', 1),
#  ('SORORITY QUEEN', 184, 'NC-17', 1),
#  ('SCALAWAG DUCK', 183, 'NC-17', 5),
#  ('WIFE TURN', 183, 'NC-17', 5),
#  ('SEARCHERS WAIT', 182, 'NC-17', 7),
#  ('RUNAWAY TENENBAUMS', 181, 'NC-17', 8),
#  ('ALLEY EVOLUTION', 180, 'NC-17', 9),
#  ('CONFIDENTIAL INTERVIEW', 180, 'NC-17', 9),
#  ('SOMETHING DUCK', 180, 'NC-17', 9),
#  ('ANONYMOUS HUMAN', 179, 'NC-17', 12),
#  ('REDEMPTION COMFORTS', 179, 'NC-17', 12),
#  ('TEXAS WATCH', 179, 'NC-17', 12),
#  ('YOUTH KICK', 179, 'NC-17', 12),
#  ('DOZEN LION', 177, 'NC-17', 16),
#  ('WRATH MILE', 176, 'NC-17', 17),
#  ('DRIVING POLISH', 175, 'NC-17', 18),
#  ('LAWRENCE LOVE', 175, 'NC-17', 18),
#  ('MODEL FISH', 175, 'NC-17', 18),
#  ('JADE BUNCH', 174, 'NC-17', 21),
#  ('UPRISING UPTOWN', 174, 'NC-17', 21),
#  ('PIZZA JUMANJI', 173, 'NC-17', 23),
#  ('CREEPERS KANE', 172, 'NC-17', 24),
#  ('JERK PAYCHECK', 172, 'NC-17', 24),
#  ('JERICHO MULAN', 171, 'NC-17', 26),
#  ('ARTIST COLDBLOODED', 170, 'NC-17', 27),
#  ('DRAGON SQUAD', 170, 'NC-17', 27),
#  ('HEDWIG ALTER', 169, 'NC-17', 29),
#  ('OUTBREAK DIVINE', 169, 'NC-17', 29),
#  ('ANTITRUST TOMATOES', 168, 'NC-17', 31),
#  ('HAROLD FRENCH', 168, 'NC-17', 31),
#  ('INCH JET', 167, 'NC-17', 33),
#  ('LESSON CLEOPATRA', 167, 'NC-17', 33),
#  ('IGBY MAKER', 160, 'NC-17', 35),
#  ('MUMMY CREATURES', 160, 'NC-17', 35),
#  ('FRANKENSTEIN STRANGER', 159, 'NC-17', 37),
#  ('ENOUGH RAGING', 158, 'NC-17', 38),
#  ('INDEPENDENCE HOTEL', 157, 'NC-17', 39),
#  ('VOLCANO TEXAS', 157, 'NC-17', 39),
#  ('ELF MURDER', 155, 'NC-17', 41),
#  ('LOLITA WORLD', 155, 'NC-17', 41),
#  ('BABY HALL', 153, 'NC-17', 43),
#  ('EDGE KISSING', 153, 'NC-17', 43),
#  ('ELIZABETH SHANE', 152, 'NC-17', 45),
#  ('LUCK OPUS', 152, 'NC-17', 45),
#  ('CHRISTMAS MOONSHINE', 150, 'NC-17', 47),
#  ('DIRTY ACE', 147, 'NC-17', 48),
#  ('LIES TREATMENT', 147, 'NC-17', 48),
#  ('RACER EGG', 147, 'NC-17', 48),
#  ('CHAPLIN LICENSE', 146, 'NC-17', 51),
#  ('NUTS TIES', 145, 'NC-17', 52),
#  ('VIDEOTAPE ARSENIC', 145, 'NC-17', 52),
#  ('TOWERS HURRICANE', 144, 'NC-17', 54),
#  ('VIRTUAL SPOILERS', 144, 'NC-17', 54),
#  ('CINCINATTI WHISPERER', 143, 'NC-17', 56),
#  ('STEEL SANTA', 143, 'NC-17', 56),
#  ('BIKINI BORROWERS', 142, 'NC-17', 58),
#  ('SPICE SORORITY', 141, 'NC-17', 59),
#  ('EAGLES PANKY', 140, 'NC-17', 60),
#  ('CREATURES SHAKESPEARE', 139, 'NC-17', 61),
#  ('DORADO NOTTING', 139, 'NC-17', 61),
#  ('HOPE TOOTSIE', 139, 'NC-17', 61),
#  ('POCUS PULP', 138, 'NC-17', 64),
#  ('LIFE TWISTED', 137, 'NC-17', 65),
#  ('SCORPION APOLLO', 137, 'NC-17', 65),
#  ('HOLLOW JEOPARDY', 136, 'NC-17', 67),
#  ('PIANIST OUTFIELD', 136, 'NC-17', 67),
#  ('CANDLES GRAPES', 135, 'NC-17', 69),
#  ('INDIAN LOVE', 135, 'NC-17', 69),
#  ('SIERRA DIVIDE', 135, 'NC-17', 69),
#  ('JUNGLE CLOSER', 134, 'NC-17', 72),
#  ('DRAGONFLY STRANGERS', 133, 'NC-17', 73),
#  ('FOREVER CANDIDATE', 131, 'NC-17', 74),
#  ('NEMO CAMPUS', 131, 'NC-17', 74),
#  ('DARKO DORADO', 130, 'NC-17', 76),
#  ('JASON TRAP', 130, 'NC-17', 76),
#  ('OUTFIELD MASSACRE', 129, 'NC-17', 78),
#  ('NOTORIOUS REUNION', 128, 'NC-17', 79),
#  ('MONTEZUMA COMMAND', 126, 'NC-17', 80),
#  ('VAMPIRE WHALE', 126, 'NC-17', 80),
#  ('WONDERFUL DROP', 126, 'NC-17', 80),
#  ('BULL SHAWSHANK', 125, 'NC-17', 83),
#  ('DONNIE ALLEY', 125, 'NC-17', 83),
#  ('GENTLEMEN STAGE', 125, 'NC-17', 83),
#  ('FLASH WARS', 123, 'NC-17', 86),
#  ('INSECTS STONE', 123, 'NC-17', 86),
#  ('MASK PEACH', 123, 'NC-17', 86),
#  ('REEF SALUTE', 123, 'NC-17', 86),
#  ('VANISHING ROCKY', 123, 'NC-17', 86),
#  ('BETRAYED REAR', 122, 'NC-17', 91),
#  ('DECEIVER BETRAYED', 122, 'NC-17', 91),
#  ('HOURS RAGE', 122, 'NC-17', 91),
#  ('VANILLA DAY', 122, 'NC-17', 91),
#  ('PURE RUNNER', 121, 'NC-17', 95),
#  ('CALENDAR GUNFIGHT', 120, 'NC-17', 96),
#  ('UNTOUCHABLES SUNRISE', 120, 'NC-17', 96),
#  ('DUMBO LUST', 119, 'NC-17', 98),
#  ('ROUGE SQUAD', 118, 'NC-17', 99),
#  ('CHAMBER ITALIAN', 117, 'NC-17', 100),
#  ('DUCK RACER', 116, 'NC-17', 101),
#  ('ELEMENT FREDDY', 115, 'NC-17', 102),
#  ('PRIDE ALAMO', 114, 'NC-17', 103),
#  ('LADYBUGS ARMAGEDDON', 113, 'NC-17', 104),
#  ('STATE WASTELAND', 113, 'NC-17', 104),
#  ('CONEHEADS SMOOCHY', 112, 'NC-17', 106),
#  ('FORRESTER COMANCHEROS', 112, 'NC-17', 106),
#  ('SEABISCUIT PUNK', 112, 'NC-17', 106),
#  ('GROOVE FICTION', 111, 'NC-17', 109),
#  ('COMA HEAD', 109, 'NC-17', 110),
#  ('PANTHER REDS', 109, 'NC-17', 110),
#  ('HANKY OCTOBER', 107, 'NC-17', 112),
#  ('BED HIGHBALL', 106, 'NC-17', 113),
#  ('DEER VIRGINIAN', 106, 'NC-17', 113),
#  ('JOON NORTHWEST', 105, 'NC-17', 115),
#  ('ZHIVAGO CORE', 105, 'NC-17', 115),
#  ('MERMAID INSECTS', 104, 'NC-17', 117),
#  ('BIRDCAGE CASPER', 103, 'NC-17', 118),
#  ('IMPOSSIBLE PREJUDICE', 103, 'NC-17', 118),
#  ('STRANGELOVE DESIRE', 103, 'NC-17', 118),
#  ('CHOCOLAT HARRY', 101, 'NC-17', 121),
#  ('RUNNER MADIGAN', 101, 'NC-17', 121),
#  ('WITCHES PANIC', 100, 'NC-17', 123),
#  ('DARKNESS WAR', 99, 'NC-17', 124),
#  ('PATIENT SISTER', 99, 'NC-17', 124),
#  ('PERDITION FARGO', 99, 'NC-17', 124),
#  ('REAR TRADING', 97, 'NC-17', 127),
#  ('EARLY HOME', 96, 'NC-17', 128),
#  ('ALICE FANTASIA', 94, 'NC-17', 129),
#  ('GREATEST NORTH', 93, 'NC-17', 130),
#  ('STING PERSONAL', 93, 'NC-17', 130),
#  ('APACHE DIVINE', 92, 'NC-17', 132),
#  ('CARIBBEAN LIBERTY', 92, 'NC-17', 132),
#  ('ENCOUNTERS CURTAIN', 92, 'NC-17', 132),
#  ('MYSTIC TRUMAN', 92, 'NC-17', 132),
#  ('NATIONAL STORY', 92, 'NC-17', 132),
#  ('SUNDANCE INVASION', 92, 'NC-17', 132),
#  ('LICENSE WEEKEND', 91, 'NC-17', 138),
#  ('FORWARD TEMPLE', 90, 'NC-17', 139),
#  ('GLEAMING JAWBREAKER', 89, 'NC-17', 140),
#  ('BANG KWAI', 87, 'NC-17', 141),
#  ('SLEUTH ORIENT', 87, 'NC-17', 141),
#  ('EARTH VISION', 85, 'NC-17', 143),
#  ('ENDING CROWDS', 85, 'NC-17', 143),
#  ('GRAIL FRANKENSTEIN', 85, 'NC-17', 143),
#  ('VARSITY TRIP', 85, 'NC-17', 143),
#  ('WONKA SEA', 85, 'NC-17', 143),
#  ('IDOLS SNATCHERS', 84, 'NC-17', 148),
#  ('ISLAND EXORCIST', 84, 'NC-17', 148),
#  ('HUSTLER PARTY', 83, 'NC-17', 150),
#  ('NONE SPIKING', 83, 'NC-17', 150),
#  ('ROMAN PUNK', 81, 'NC-17', 152),
#  ('INSIDER ARIZONA', 78, 'NC-17', 153),
#  ('LANGUAGE COWBOY', 78, 'NC-17', 153),
#  ('ENEMY ODDS', 77, 'NC-17', 155),
#  ('FELLOWSHIP AUTUMN', 77, 'NC-17', 155),
#  ('MEMENTO ZOOLANDER', 77, 'NC-17', 155),
#  ('MOD SECRETARY', 77, 'NC-17', 155),
#  ('BOONDOCK BALLROOM', 76, 'NC-17', 159),
#  ('COMFORTS RUSH', 76, 'NC-17', 159),
#  ('DESIRE ALIEN', 76, 'NC-17', 159),
#  ('HAUNTED ANTITRUST', 76, 'NC-17', 159),
#  ('BALLOON HOMEWARD', 75, 'NC-17', 163),
#  ('CALIFORNIA BIRDS', 75, 'NC-17', 163),
#  ('INFORMER DOUBLE', 74, 'NC-17', 165),
#  ('JUMPING WRATH', 74, 'NC-17', 165),
#  ('LUKE MUMMY', 74, 'NC-17', 165),
#  ('MAGUIRE APACHE', 74, 'NC-17', 165),
#  ('PEARL DESTINY', 74, 'NC-17', 165),
#  ('GODFATHER DIARY', 73, 'NC-17', 170),
#  ('RANDOM GO', 73, 'NC-17', 170),
#  ('BOWFINGER GABLES', 72, 'NC-17', 172),
#  ('PRINCESS GIANT', 71, 'NC-17', 173),
#  ('CLUE GRAIL', 70, 'NC-17', 174),
#  ('GUNFIGHT MOON', 70, 'NC-17', 174),
#  ('FLYING HOOK', 69, 'NC-17', 176),
#  ('ARK RIDGEMONT', 68, 'NC-17', 177),
#  ('HUMAN GRAFFITI', 68, 'NC-17', 177),
#  ('NORTH TEQUILA', 67, 'NC-17', 179),
#  ('FREDDY STORM', 65, 'NC-17', 180),
#  ('HUNTING MUSKETEERS', 65, 'NC-17', 180),
#  ('CRAFT OUTFIELD', 64, 'NC-17', 182),
#  ('ALADDIN CALENDAR', 63, 'NC-17', 183),
#  ('ARABIA DOGMA', 62, 'NC-17', 184),
#  ('MARS ROMAN', 62, 'NC-17', 184),
#  ('CAMELOT VACATION', 61, 'NC-17', 186),
#  ('CASSIDY WYOMING', 61, 'NC-17', 186),
#  ('PHANTOM GLORY', 60, 'NC-17', 188),
#  ('PITY BOUND', 60, 'NC-17', 188),
#  ('DANCES NONE', 58, 'NC-17', 190),
#  ('CRANES RESERVOIR', 57, 'NC-17', 191),
#  ('STORM HAPPINESS', 57, 'NC-17', 191),
#  ('WOLVES DESIRE', 55, 'NC-17', 193),
#  ('BENEATH RUSH', 53, 'NC-17', 194),
#  ('CABIN FLASH', 53, 'NC-17', 194),
#  ('GUMP DATE', 53, 'NC-17', 194),
#  ('CADDYSHACK JEDI', 52, 'NC-17', 197),
#  ('SPARTACUS CHEAPER', 52, 'NC-17', 197),
#  ('WESTWARD SEABISCUIT', 52, 'NC-17', 197),
#  ('HALL CASSIDY', 51, 'NC-17', 200),
#  ('SIMON NORTH', 51, 'NC-17', 200),
#  ('ADAPTATION HOLES', 50, 'NC-17', 202),
#  ('ZORRO ARK', 50, 'NC-17', 202),
#  ('DOORS PRESIDENT', 49, 'NC-17', 204),
#  ('HEAVENLY GUN', 49, 'NC-17', 204),
#  ('ODDS BOOGIE', 48, 'NC-17', 206),
#  ('STEPMOM DREAM', 48, 'NC-17', 206),
#  ('SUNSET RACER', 48, 'NC-17', 206),
#  ('HANOVER GALAXY', 47, 'NC-17', 209),
#  ('ALIEN CENTER', 46, 'NC-17', 210)]

# %%
# %%sql
# -- 3
# select name as category_name, count(*) as num_films
# from sakila.category inner join sakila.film_category using (category_id)
# group by name
# order by num_films desc;
# Out:
#  * mysql+pymysql://root:***@localhost/bank
# 16 rows affected.
# [('Sports', 74),
#  ('Foreign', 73),
#  ('Family', 69),
#  ('Documentary', 68),
#  ('Animation', 66),
#  ('Action', 64),
#  ('New', 63),
#  ('Drama', 62),
#  ('Games', 61),
#  ('Sci-Fi', 61),
#  ('Children', 60),
#  ('Comedy', 58),
#  ('Classics', 57),
#  ('Travel', 57),
#  ('Horror', 56),
#  ('Music', 51)]

# %%
# %%sql
# -- 4
# select actor.actor_id, actor.first_name, actor.last_name,
# count(actor_id) as film_count
# from sakila.actor join sakila.film_actor using (actor_id)
# group by actor_id
# order by film_count desc
# limit 1;
# Out:
#  * mysql+pymysql://root:***@localhost/bank
# 1 rows affected.
# [(107, 'GINA', 'DEGENERES', 42)]

# %%
# %%sql
# -- 5
# select customer.*,
# count(rental_id) as rental_count
# from sakila.customer join sakila.rental using (customer_id)
# group by customer_id
# order by rental_count desc
# limit 1;
# Out:
#  * mysql+pymysql://root:***@localhost/bank
# 1 rows affected.
# [(148, 1, 'ELEANOR', 'HUNT', 'ELEANOR.HUNT@sakilacustomer.org', 152, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20), 46)]

# %%
# %%sql
# -- BONUS
# select film.title, count(rental_id) as rental_count
# from sakila.film inner join sakila.inventory using (film_id)
# inner join sakila.rental using (inventory_id)
# group by film_id
# order by rental_count desc
# limit 1;
# Out:
#  * mysql+pymysql://root:***@localhost/bank
# 1 rows affected.
# [('BUCKET BROTHERHOOD', 34)]
